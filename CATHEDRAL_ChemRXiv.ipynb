# %% [markdown]
# # Improving the chemical profiling of complex natural extracts by joint 13C NMR and LC-HRMS2 analysis and the querying of in silico generated chemical databases.
#
# #### Julien Cordonnier,a,b  Simon Remy,b* Alexis Kotland,d Ritchy Leroy,b Pierre Darme,a,b, Benjamin Ber-taux,b Charlotte Sayagh,b Agathe Martinez,b Nicolas Borie,b Jane Hubert,d Dominique Aubert,a,c Isa-belle Villena,a,c Jean-Marc Nuzillard,b Jean-Hugues Renault b*
#
# ##### a University of Reims Champagne Ardenne, ESCAPE EA7510, 51097 Reims, France
# ##### b University of Reims Champagne Ardenne, CNRS, ICMR 7312, 51097 Reims, France
# ##### c University of Reims Champagne Ardenne, CRB National reference Centre on Toxoplasmosis, 51097 Reims, France
# ##### d NatExplore, 51140 Prouilly, France
# ##### *Correspondence should be addressed to S.R. (simon.remy@univ-reims.fr)
#
#
# #             CATHEDRAL
#
# ## This script was developped for the cross-validation of annotations coming from different annotation tools (FBMN, NAP, SIRIUS, CaraMel), while the dereplication workflow.
#
# #### This workflow has been developped by PhD student Julien Cordonnier and the CSN lab (ICMR - UMR CNRS 7312 - Université de Reims Champagne Ardenne, FRANCE).

# %% [markdown]
# Depending of which annotation tools you have used, some of the following steps may not be necessary.
#
# Please check before starting:
#   - that you run the following script in a RDKit environment. If not, take a look at https://www.rdkit.org/docs/Install.html#how-to-install-rdkit-with-conda
#   - all the necessary packages are installed in the environment (math, pandas, glob, stat, tqdm).
#
# ##### /!\ The only 4 paths you will have to replace are: /!\
#  - the path to your recap file  **/!\ This file should be placed in the current directory /!\**
#  - the path to your SIRIUS project folder (must end with /*) .
#  - the path to your 13C NMR candidates file
#  - the path to save the comparison results
#
# ##### These paths must be informed in the cell below.

# %%
recap_file_path = './recap230106.csv'
sirus_project_path ='C:/Users/jcrdnr/Desktop/Experimental_Data_Larix_decidua/sirius_190922/*'
CNMR_candidates_path ='C:/Users/jcrdnr/Desktop/Experimental_Data_Larix_decidua/smile_23_nmr_iso.txt'
resume_file_path ='C:/Users/jcrdnr/Desktop/article_larix/230413/SI/Scripts/df_resume_confidence_230814.tsv'

# %%
# recap_file_path = input('Please, enter the path for the recap.csv file. ')
# sirus_project_path = input('Please, enter the path to your SIRIUS project. (must end with /*) ')
# CNMR_candidates_path = input('Please, enter the path for the 13C NMR candidates file. ')
# resume_file_path = input('Please, enter the path to save the comparisons resume. ')

# %% [markdown]
# ## → First step, import the required packages

# %%
import math
import pandas as pd
import rdkit
import os
import glob
import sys
import stat
from tqdm import tqdm
from rdkit.Chem import AllChem as Chem

# %% [markdown]
# ## → Create a blank dataframe that will resume the cross-validation results

# %%
Dict_sumup = {
    'Feature_SU':{},
    'm/z':{},
    'Rt_SU':{},
    'GNPS_SU':{},
    'NAP_SU':{},
    'MolNetEnhancer_SU':{},
    'SIRIUS_SU':{},
    'Not_Matching_Tool_Annotation_SU':{},
    'Is_NMR_Annotated_SU':{},
    '3rd_Tool_SU':{},
    'Molecular_Name_SU':{},
    'Confidence_Level':{}
                }

# %% [markdown]
# ## /!\ Open the recap metadata file that merges the metadata coming from IIMN, FBMN, NAP, MolNetEnhancer /!\
#
# ## /!\ This file should be placed in the current directory /!\
# Just replace the red name between quotation marks in the cell bellow.
#
# Final *confidence score*  is set to  0 by default

# %%
df = pd.read_csv(recap_file_path, sep=';')
df['All_Tools_confidence'] = 0

# %% [markdown]
# If you want to vizualize the dataframe, run the cell bellow

# %%
df.head()
# Out:
#   Adduct  AllGroups Analog:Adduct Analog:Compound_Name Analog:Compound_Source  \
# 0    NaN        NaN           NaN                  NaN                    NaN
# 1    NaN        NaN           NaN                  NaN                    NaN
# 2    NaN        NaN           NaN                  NaN                    NaN
# 3    M+H        NaN           NaN                  NaN                    NaN
# 4    NaN        NaN           NaN                  NaN                    NaN
#
#   Analog:Data_Collector Analog:GNPSLibraryURL  \
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN
#
#   Analog:IIN Best Ion=Library Adduct Analog:INCHI Analog:Instrument  ...  \
# 0                                NaN          NaN               NaN  ...
# 1                                NaN          NaN               NaN  ...
# 2                                NaN          NaN               NaN  ...
# 3                                NaN          NaN               NaN  ...
# 4                                NaN          NaN               NaN  ...
#
#   sum(precursor intensity) sum.precursor.intensity.  \
# 0              4117.484887                      NaN
# 1             41457.667200                      NaN
# 2              5492.948748                      NaN
# 3             21911.786750                      NaN
# 4              1111.107542                      NaN
#
#                          superclass  tags  TIC_Query  UniqueFileSources  \
# 0                               NaN   NaN        NaN                NaN
# 1                               NaN   NaN        NaN                NaN
# 2                               NaN   NaN        NaN                NaN
# 3  Phenylpropanoids and polyketides   NaN     4141.0                NaN
# 4                               NaN   NaN        NaN                NaN
#
#   Unnamed: 25              UpdateWorkflowName PRED All_Tools_confidence
# 0         NaN                             NaN    3                    0
# 1         NaN                             NaN    3                    0
# 2         NaN                             NaN    3                    0
# 3         NaN  UPDATE-SINGLE-ANNOTATED-BRONZE    1                    0
# 4         NaN                             NaN    3                    0
#
# [5 rows x 147 columns]

# %% [markdown]
# ## 1. If your data contains GNPS annotations through the FBMN and/or IIMN, you should run the following cells.
# This will select the corresponding features (PRED value = 1).
#
# **/!\**  If your data contains NAP annotations, the present script is working with **maximum 3 MetFrag candidates** **/!\**
#
# **/!\** Fusion and Consensus candidates will not be considered **/!\**

# %%
df1=df.loc[df['PRED']==1]
if len(df1['MetFragID'].tolist()) != 0:
    df1[['MetFragID1', 'MetFragID2', 'MetFragID3']] = df1['MetFragID'].str.split(',', expand=True)
    df1[['MetFragSMILES1', 'MetFragSMILES2', 'MetFragSMILES3']] = df1['MetFragSMILES'].str.split(',', expand=True)
# Out:
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2951615403.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['MetFragID1', 'MetFragID2', 'MetFragID3']] = df1['MetFragID'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2951615403.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['MetFragID1', 'MetFragID2', 'MetFragID3']] = df1['MetFragID'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2951615403.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['MetFragID1', 'MetFragID2', 'MetFragID3']] = df1['MetFragID'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2951615403.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['MetFragSMILES1', 'MetFragSMILES2', 'MetFragSMILES3']] = df1['MetFragSMILES'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2951615403.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['MetFragSMILES1', 'MetFragSMILES2', 'MetFragSMILES3']] = df1['MetFragSMILES'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2951615403.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['MetFragSMILES1', 'MetFragSMILES2', 'MetFragSMILES3']] = df1['MetFragSMILES'].str.split(',', expand=True)

# %% [markdown]
# ### 1.1 If your data contains NAP MetFrag annotations, please run the following cell to compare them to FBMN / IIMN annotations.

# %%
list_ID1=[]
for i in range(len(df1['shared name'].tolist())):
    
    
    if '.' in df1['Smiles'].tolist()[i]:
        smiles = df1['Smiles'].tolist()[i].split('.')[0]
    else:
        smiles = str(df1['Smiles'].tolist()[i])
#     print(smiles)
    mref=Chem.MolFromSmiles(smiles)
    iref=Chem.MolToInchi(mref)
    ikref=Chem.rdinchi.InchiToInchiKey(iref).split('-')[0]
    
    
    
    if df1['MetFragSMILES1'].tolist()[i] != None:
        try:

            m1=Chem.MolFromSmiles(df1['MetFragSMILES1'].tolist()[i])
            i1=Chem.MolToInchi(m1)
            ik1=Chem.rdinchi.InchiToInchiKey(i1).split('-')[0]
            if ik1 == ikref:
                LID1 = 'MetFrag_1_'+df1['MetFragID1'].tolist()[i]
                list_ID1.append((int(df1['shared name'].tolist()[i]),LID1, df1['MetFragSMILES1'].tolist()[i]))
        except:
            continue
        
            
    if df1['MetFragSMILES2'].tolist()[i] != None:   
        try:

            m2=Chem.MolFromSmiles(df1['MetFragSMILES2'].tolist()[i])
            i2=Chem.MolToInchi(m2)
            ik2=Chem.rdinchi.InchiToInchiKey(i2).split('-')[0]
            if ik2 == ikref:
                LID2= 'MetFrag_2_'+df1['MetFragID2'].tolist()[i]
                list_ID1.append((int(df1['shared name'].tolist()[i]), LID2, df1['MetFragSMILES2'].tolist()[i]))
            
        except:
            continue
        
        
    if df1['MetFragSMILES3'].tolist()[i] != None:   
        try:

            m3=Chem.MolFromSmiles(df1['MetFragSMILES3'].tolist()[i])
            i3=Chem.MolToInchi(m3)
            ik3=Chem.rdinchi.InchiToInchiKey(i3).split('-')[0]
            if ik3 == ikref:
                LID3 = 'MetFrag_3_'+df1['MetFragID3'].tolist()[i]
                list_ID1.append(int((df1['shared name'].tolist()[i]), LID3, df1['MetFragSMILES3'].tolist()[i]))
        except:
            continue
# Out:
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo

# %% [markdown]
# If you want to vizualize the comparison results, run the cell bellow.
#
# Results are presented as a tupple (FeatureID, MetFrag candidate, SMILES of the candidate).

# %%
list_ID1
# Out:
# [(190, 'MetFrag_2_LTS0004651', 'O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc(O)cc(O)c12'),
#  (51,
#   'MetFrag_1_LTS0066122',
#   'Oc1cc(O)c2c(c1)O[C@H](c1ccc(O)c(O)c1)[C@H](O)[C@H]2c1c(O)cc(O)c2c1O[C@H](c1ccc(O)c(O)c1)[C@@H](O)C2'),
#  (283, 'MetFrag_1_LTS0155822', 'O=c1c(O)c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12'),
#  (367, 'MetFrag_1_LTS0155822', 'O=c1c(O)c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12'),
#  (60,
#   'MetFrag_1_LTS0265245',
#   'Oc1cc(O)c2c(c1)O[C@H](c1ccc(O)c(O)c1)[C@H](O)C2'),
#  (136,
#   'MetFrag_1_LTS0066122',
#   'Oc1cc(O)c2c(c1)O[C@H](c1ccc(O)c(O)c1)[C@H](O)[C@H]2c1c(O)cc(O)c2c1O[C@H](c1ccc(O)c(O)c1)[C@@H](O)C2'),
#  (237,
#   'MetFrag_1_LTS0186298',
#   'CC1OC(Oc2c(-c3ccc(O)c(O)c3)oc3cc(O)cc(O)c3c2=O)C(O)C(O)C1O'),
#  (220, 'MetFrag_2_LTS0004651', 'O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc(O)cc(O)c12')]

# %% [markdown]
# ### 1.2 If your data were annotated with SIRIUS (following the format from the 5.5.3 version), you would like to compare these annotations to FBMN / IIMN ones.
# Please run the following cells.

# %% [markdown]
# ##### /!\ Open the corresponding SIRIUS project folder /!\

# %%
files = glob.glob(sirus_project_path)
list_folder = [file for file in files if '.' not in str(file)]
print('There are '+ str(len(list_folder)) + ' features in your SIRIUS project. ')
# Out:
# There are 1915 features in your SIRIUS project.

# %%
list_sirius_inchikey=[]
for i in range(len(df1['shared name'].tolist())):
    

    
    if '.' in df1['Smiles'].tolist()[i]:
        smiles = df1['Smiles'].tolist()[i].split('.')[0]
    else:
        smiles = df1['Smiles'].tolist()[i]
    mref=Chem.MolFromSmiles(smiles)
    iref=Chem.MolToInchi(mref)
    ikref=Chem.rdinchi.InchiToInchiKey(iref).split('-')[0]

    
    

    filein =[x for x in list_folder if  str('_' + str(int(df1['shared name'].tolist()[i]))) == x[-len(str('_' + str(int(df1['shared name'].tolist()[i])))):]]
    
    if len(filein) != 0:
        
        os.chmod(filein[0], stat.S_IROTH)

        if os.path.exists(filein[0]+'/structure_candidates.tsv'):
           
            df_sirius_formula = pd.read_csv(filein[0]+'/structure_candidates.tsv', sep='\t')


            for z in range(len(df_sirius_formula['InChIkey2D'].tolist())):
                
                if df_sirius_formula['InChIkey2D'].tolist()[z] == ikref:
                    aa = str(df_sirius_formula['InChIkey2D'].tolist()[z]) + '_structure_' + str(df_sirius_formula['molecularFormula'].tolist()[z]) +  df_sirius_formula['adduct'].tolist()[z] 

                    list_sirius_inchikey.append((int(df1['shared name'].tolist()[i]),aa))
# Out:
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:20] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo

# %% [markdown]
# If you want to vizualize the comparison results, run the cell bellow.
#
# Results are presented as a tupple (FeatureID, InChIKey of the matching candidate + chemical formula + adduct type).

# %%
list_sirius_inchikey
# Out:
# [(343, 'REFJWTPEDVJJIY_structure_C15H10O7[M + H]+'),
#  (190, 'REFJWTPEDVJJIY_structure_C15H10O7[M + H]+'),
#  (422, 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+'),
#  (51, 'XFZJEEAOWLFHDH_structure_C30H26O12[M + H]+'),
#  (488, 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+'),
#  (283, 'IYRMWMYZSQPJKC_structure_C15H10O6[M + H]+'),
#  (367, 'IYRMWMYZSQPJKC_structure_C15H10O6[M + H]+'),
#  (182, 'IKGXIBQEEMLURG_structure_C27H30O16[M + H]+'),
#  (867, 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+'),
#  (334, 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+'),
#  (426, 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+'),
#  (60, 'PFTAWBLQPZVEMU_structure_C15H14O6[M + H]+'),
#  (136, 'XFZJEEAOWLFHDH_structure_C30H26O12[M + H]+'),
#  (720, 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+'),
#  (569, 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+'),
#  (237, 'OXGUCUVFOIWWQJ_structure_C21H20O11[M + H]+'),
#  (220, 'REFJWTPEDVJJIY_structure_C15H10O7[M + H]+'),
#  (1366, 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+'),
#  (280, 'OVSQVDMCBVZWGM_structure_C21H20O12[M + H]+'),
#  (239, 'IYRMWMYZSQPJKC_structure_C15H10O6[M + H]+')]

# %% [markdown]
# ### 1.3 If your data were annotated with FBMN / IIMN, NAP and SIRIUS (following the format from the 5.5.3 version), you would like to compare them all together.
# Please run the following cells.

# %% [markdown]
# #### 1.3.1 Which nodes are only GNPS_NAP or only GNPS_SIRIUS common ?

# %%
common=[z[0] for z in list_ID1 if z[0] in [x[0] for x in list_sirius_inchikey]] 
not_common_NAP_pro=[z[0] for z in list_ID1 if z[0] not in [x[0] for x in list_sirius_inchikey]]
not_common_SIRIUS_pro=[z[0] for z in list_sirius_inchikey if z[0] not in [x[0] for x in list_ID1]]   

print(str('Features that have only GNPS_NAP common annotation are: ' + str(not_common_NAP_pro)) + '\n' +  str('Features that have only GNPS_SIRIUS common annotation are: ' + 
str(not_common_SIRIUS_pro)))
# Out:
# Features that have only GNPS_NAP common annotation are: []
# Features that have only GNPS_SIRIUS common annotation are: [343, 422, 488, 182, 867, 334, 426, 720, 569, 1366, 280, 239]

# %% [markdown]
# #### 1.3.2 Which nodes are GNPS_NAP_SIRIUS common ?
# Results are presented as a tupple: (FeatureID, GNPS matched ref spectra, MetFrag candidate, InChiKey + chemical formula + adduct type)

# %%
common_sumup=[]
for a in common:
    gnps = df1['SpectrumID'].tolist()[df1['shared name'].tolist().index(a)]
    for x in list_ID1:
        if x[0] == a:
            b=x[1]
    for y in list_sirius_inchikey:
        if y[0] ==a:
            c = y[1]
    common_sumup.append((int(a),gnps,b,c))

common_sumup
# Out:
# [(190,
#   'CCMSLIB00005739139',
#   'MetFrag_2_LTS0004651',
#   'REFJWTPEDVJJIY_structure_C15H10O7[M + H]+'),
#  (51,
#   'CCMSLIB00005742589',
#   'MetFrag_1_LTS0066122',
#   'XFZJEEAOWLFHDH_structure_C30H26O12[M + H]+'),
#  (283,
#   'CCMSLIB00005748053',
#   'MetFrag_1_LTS0155822',
#   'IYRMWMYZSQPJKC_structure_C15H10O6[M + H]+'),
#  (367,
#   'CCMSLIB00005749366',
#   'MetFrag_1_LTS0155822',
#   'IYRMWMYZSQPJKC_structure_C15H10O6[M + H]+'),
#  (60,
#   'CCMSLIB00005742701',
#   'MetFrag_1_LTS0265245',
#   'PFTAWBLQPZVEMU_structure_C15H14O6[M + H]+'),
#  (136,
#   'CCMSLIB00005742589',
#   'MetFrag_1_LTS0066122',
#   'XFZJEEAOWLFHDH_structure_C30H26O12[M + H]+'),
#  (237,
#   'CCMSLIB00000085852',
#   'MetFrag_1_LTS0186298',
#   'OXGUCUVFOIWWQJ_structure_C21H20O11[M + H]+'),
#  (220,
#   'CCMSLIB00005739139',
#   'MetFrag_2_LTS0004651',
#   'REFJWTPEDVJJIY_structure_C15H10O7[M + H]+')]

# %% [markdown]
# ##### Write results in the resume file.

# %%
numerous=-1
for x in range(len(common_sumup)):
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(common_sumup[x][0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=common_sumup[x][1]
    Dict_sumup['NAP_SU'][numerous]=str(common_sumup[x][2].split('_')[2] + ' MF' +  str(common_sumup[x][2].split('_')[1]))
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
    Dict_sumup['SIRIUS_SU'][numerous]=common_sumup[x][3].split('_')[0] + ' ' + common_sumup[x][3].split('_')[2]
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]=None
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]=None
    Dict_sumup['3rd_Tool_SU'][numerous]=None
    Dict_sumup['Molecular_Name_SU'][numerous]=None
    Dict_sumup['Confidence_Level'][numerous]=str(9)

# %% [markdown]
# ##### Apply confidence score = 9 to all nodes that have GNPS_NAP_SIRIUS common annotation

# %%
for x in common_sumup:
    df['All_Tools_confidence'][df['shared name'].tolist().index(x[0])] = 9
# Out:
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3096177141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['All_Tools_confidence'][df['shared name'].tolist().index(x[0])] = 9 ### au lieu de & 230814

# %% [markdown]
# #### 1.3.3 Get the informations for the features that only have GNPS_NAP common annotation (cf. 1.3.1)

# %%
GNPS_NAP_common_sumup=[]
for a in not_common_NAP_pro:
    gnps = df1['SpectrumID'].to_list()[df1['shared name'].to_list().index(a)]
    for x in list_ID1:
        if x[0] == a:
            b=x[1]
            c=x[2]

    GNPS_NAP_common_sumup.append((a,gnps,b,c))

if len(GNPS_NAP_common_sumup) == 0:
    print('There is no common annotations between GNPS and NAP workflows.')
else:
    print(f'There are {len(GNPS_NAP_common_sumup)} that only have common annotations between GNPS and NAP workflows.' + '\n')
    for x in GNPS_NAP_common_sumup:
        print(x)
# Out:
# There is no common annotations between GNPS and NAP workflows.

# %% [markdown]
# ##### Write results in the resume file.

# %%
for x in range(len(GNPS_NAP_common_sumup)):
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(GNPS_NAP_common_sumup[x][0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=GNPS_NAP_common_sumup[x][1]
    Dict_sumup['NAP_SU'][numerous]=str(GNPS_NAP_common_sumup[x][2].split('_')[2] + ' MF' +  str(GNPS_NAP_common_sumup[x][2].split('_')[1]))
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
    Dict_sumup['SIRIUS_SU'][numerous]=None
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]='SIRIUS'
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]=None
    Dict_sumup['3rd_Tool_SU'][numerous]=None
    Dict_sumup['Molecular_Name_SU'][numerous]=None
    Dict_sumup['Confidence_Level'][numerous]=str(12)

# %% [markdown]
# ##### Apply confidence score = 10 to all nodes that only have GNPS_NAP common annotation

# %%
for x in GNPS_NAP_common_sumup:
    df['All_Tools_confidence'][df['shared name'].to_list().index(x[0])] = 12

# %% [markdown]
# #### 1.3.4 Get the informations for the features that only have GNPS_SIRIUS common annotation (cf. 1.3.1)

# %%
GNPS_SIRIUS_common_sumup=[]
for a in not_common_SIRIUS_pro:
    gnps = df1['SpectrumID'].tolist()[df1['shared name'].tolist().index(a)]

    for y in list_sirius_inchikey:
        if y[0] ==a:
            c = y[1]
    GNPS_SIRIUS_common_sumup.append((a,gnps,c))
if len(GNPS_SIRIUS_common_sumup) == 0:
    print('There is no common annotations between GNPS and SIRIUS workflows.')
else:
    print(f'There are {len(GNPS_SIRIUS_common_sumup)} fetaures that only have common annotation between GNPS aand SIRIUS workflows' + '\n')
    for x in GNPS_SIRIUS_common_sumup:
        print(x)
# Out:
# There are 12 fetaures that only have common annotation between GNPS aand SIRIUS workflows
#
# (343, 'CCMSLIB00005745873', 'REFJWTPEDVJJIY_structure_C15H10O7[M + H]+')
# (422, 'CCMSLIB00006570644', 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+')
# (488, 'CCMSLIB00006570644', 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+')
# (182, 'CCMSLIB00000222082', 'IKGXIBQEEMLURG_structure_C27H30O16[M + H]+')
# (867, 'CCMSLIB00006570661', 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+')
# (334, 'CCMSLIB00006570644', 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+')
# (426, 'CCMSLIB00006570644', 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+')
# (720, 'CCMSLIB00006570644', 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+')
# (569, 'CCMSLIB00006570644', 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+')
# (1366, 'CCMSLIB00006570644', 'ZQHJXKYYELWEOK_structure_C20H28O3[M + H]+')
# (280, 'CCMSLIB00005739276', 'OVSQVDMCBVZWGM_structure_C21H20O12[M + H]+')
# (239, 'CCMSLIB00005749366', 'IYRMWMYZSQPJKC_structure_C15H10O6[M + H]+')

# %% [markdown]
# ##### Write results in the resume file.

# %%
for x in range(len(GNPS_SIRIUS_common_sumup)):
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(GNPS_SIRIUS_common_sumup[x][0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=GNPS_SIRIUS_common_sumup[x][1]
    Dict_sumup['NAP_SU'][numerous]=None
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
    Dict_sumup['SIRIUS_SU'][numerous]=str(GNPS_SIRIUS_common_sumup[x][2].split('_')[0] + ' ' + GNPS_SIRIUS_common_sumup[x][2].split('_')[2])
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]='NAP'
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]=None
    Dict_sumup['3rd_Tool_SU'][numerous]=None
    Dict_sumup['Molecular_Name_SU'][numerous]=None
    Dict_sumup['Confidence_Level'][numerous]=str(10)

# %% [markdown]
# ##### Apply confidence score = 10 to all nodes that only have GNPS_SIRIUS common annotation

# %%
for x in GNPS_SIRIUS_common_sumup:
    df['All_Tools_confidence'][df['shared name'].tolist().index(x[0])] = 10
# Out:
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1317815097.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['All_Tools_confidence'][df['shared name'].tolist().index(x[0])] = 10 ### au lieu de 2 230814

# %% [markdown]
# #### 1.3.5 Get the informations for the features that only have NAP_SIRIUS common annotation

# %%
all_common = []
for x in common:
    all_common.append(x)
for x in not_common_NAP_pro:
    all_common.append(x)
for x in not_common_SIRIUS_pro:
    all_common.append(x)
    
not_common=[x for x in df1['shared name'].tolist() if x not in all_common ]

# %%
list_ID2=[]
list_ID3=[]
list_ID4=[]
for x in not_common:  

    ik1,ik2,ik3='', '',''
    if df1['MetFragSMILES1'].tolist()[df1['shared name'].tolist().index(x)] != None:
        try:
             
            m1=Chem.MolFromSmiles(df1['MetFragSMILES1'].tolist()[df1['shared name'].tolist().index(x)])
            i1=Chem.MolToInchi(m1)
            ik1=Chem.rdinchi.InchiToInchiKey(i1).split('-')[0]
            

        except:
            continue
        
            
    if df1['MetFragSMILES2'].tolist()[df1['shared name'].tolist().index(x)]!= None:   
        try:
            
            m2=Chem.MolFromSmiles(df1['MetFragSMILES2'].tolist()[df1['shared name'].tolist().index(x)])
            i2=Chem.MolToInchi(m2)
            ik2=Chem.rdinchi.InchiToInchiKey(i2).split('-')[0]
            

            
        except:
            continue
        
        
    if df1['MetFragSMILES3'].tolist()[df1['shared name'].tolist().index(x)]!= None:   
        try:
             
            m3=Chem.MolFromSmiles(df1['MetFragSMILES3'].tolist()[df1['shared name'].tolist().index(x)])
            i3=Chem.MolToInchi(m3)
            ik3=Chem.rdinchi.InchiToInchiKey(i3).split('-')[0]
            

        except:
            continue
    list_ID3.append(x)
    list_ID2.append([ik1, ik2, ik3])
    
    LMF1 = df1['MetFragID1'].tolist()[df1['shared name'].tolist().index(x)]
    LMF2=df1['MetFragID2'].tolist()[df1['shared name'].tolist().index(x)]
    LMF3=df1['MetFragID3'].tolist()[df1['shared name'].tolist().index(x)]
    list_ID4.append([LMF1, LMF2, LMF3])
# Out:
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo
#
# [16:42:21] WARNING: Omitted undefined stereo

# %%
NAP_SIRIUS_sumup=[]
list_sirius_inchikey3=[]
for ID in list_ID3: 

    filein =[x for x in list_folder if  str('_' + str(int(ID))) == x[-len(str('_' + str(int(ID)))):]]
    if len(filein)!=0:
        os.chmod(filein[0], stat.S_IROTH)

        if os.path.exists(filein[0]+'/structure_candidates.tsv'):
            df_sirius_formula = pd.read_csv(filein[0]+'/structure_candidates.tsv', sep='\t')

            aa=[]
            for z in range(len(df_sirius_formula['InChIkey2D'].tolist())):
                if df_sirius_formula['InChIkey2D'].tolist()[z] in list_ID2[list_ID3.index(ID)]:
                    aa1 = (str('MetFragSMILES_' + str(list_ID2[list_ID3.index(ID)].index(df_sirius_formula['InChIkey2D'].tolist()[z])+1) + '_' +  list_ID4[list_ID3.index(ID)][list_ID2[list_ID3.index(ID)].index(df_sirius_formula['InChIkey2D'].tolist()[z])] +' , '+ str(df_sirius_formula['InChIkey2D'].tolist()[z]) + '_structure_' + str(df_sirius_formula['molecularFormula'].tolist()[z]) + df_sirius_formula['adduct'].tolist()[z] ))

                    list_sirius_inchikey3.append(ID)
                    aa.append([aa1])
                else:
                    aa1=''

                
            if len(aa) !=0:
                NAP_SIRIUS_sumup.append((int(ID), aa))


if len(NAP_SIRIUS_sumup) == 0 :
        print('There is no feature that only have common annotations between NAP and SIRIUS.')
else:
    print(f'There are {len(NAP_SIRIUS_sumup)} features that only have NAP_SIRIUS common annotation, with a different FBMN, IIMN candidate.' + '\n')
    for x in NAP_SIRIUS_sumup:
        print(x)
# Out:
# There are 16 features that only have NAP_SIRIUS common annotation, with a different FBMN, IIMN candidate.
#
# (1453, [['MetFragSMILES_2_LTS0199022 , MJYADMFNVYHSAP_structure_C30H48O4[M + H]+'], ['MetFragSMILES_1_LTS0198220 , IQWUFDBPSLWCGM_structure_C30H48O4[M + H]+']])
# (666, [['MetFragSMILES_2_LTS0142664 , BYQLYGRDILHOFF_structure_C20H30O3[M + H]+'], ['MetFragSMILES_3_LTS0092318 , WUENWZUJMIZJPA_structure_C20H30O3[M + H]+'], ['MetFragSMILES_1_LTS0120852 , GDAJTKZIGQRGOD_structure_C20H30O3[M + H]+']])
# (1373, [['MetFragSMILES_2_LTS0240388 , RGXBCSRGWBMBCF_structure_C30H46O4[M + H]+'], ['MetFragSMILES_1_LTS0160555 , UPHZQTDFAGIZQK_structure_C30H46O4[M + H]+'], ['MetFragSMILES_3_LTS0266507 , VGVAABHRCNAZRM_structure_C30H46O4[M + H]+']])
# (750, [['MetFragSMILES_1_LTS0088733 , NGBRPGLXCQJIPU_structure_C20H26O2[M + H]+']])
# (1268, [['MetFragSMILES_3_LTS0193403 , FMUNNDDBCLRMSL_structure_C30H50O2[M + H]+'], ['MetFragSMILES_2_LTS0008250 , FVWJYYTZTCVBKE_structure_C30H50O2[M + H]+'], ['MetFragSMILES_1_LTS0168758 , CISYXFSTZZQVIH_structure_C30H50O2[M + H]+']])
# (497, [['MetFragSMILES_1_LTS0088733 , NGBRPGLXCQJIPU_structure_C20H26O2[M + H]+']])
# (1351, [['MetFragSMILES_1_LTS0220552 , IQVKGPHVUDYNPT_structure_C26H40O6[M + Na]+'], ['MetFragSMILES_3_LTS0201681 , NASOHMFLGZORKU_structure_C26H40O6[M + Na]+'], ['MetFragSMILES_2_LTS0034815 , AHBQIYSLXQMIEO_structure_C26H40O6[M + Na]+']])
# (1402, [['MetFragSMILES_3_LTS0046650 , MLBYBBUZURKHAW_structure_C20H30O2[M + H]+'], ['MetFragSMILES_2_LTS0255119 , RWWVEQKPFPXLGL_structure_C20H30O2[M + H]+'], ['MetFragSMILES_1_LTS0203405 , FKCPLBHSZGVMNG_structure_C20H30O2[M + H]+']])
# (1318, [['MetFragSMILES_3_LTS0193403 , FMUNNDDBCLRMSL_structure_C30H50O2[M + H]+'], ['MetFragSMILES_2_LTS0008250 , FVWJYYTZTCVBKE_structure_C30H50O2[M + H]+'], ['MetFragSMILES_1_LTS0168758 , CISYXFSTZZQVIH_structure_C30H50O2[M + H]+']])
# (822, [['MetFragSMILES_1_LTS0108097 , PTQFIYQNKVSVGM_structure_C19H26O2[M + H]+']])
# (893, [['MetFragSMILES_1_LTS0171116 , SGCHZBKQDFNHSL_structure_C19H26O3[M + Na]+']])
# (184, [['MetFragSMILES_2_LTS0241372 , OVSQVDMCBVZWGM_structure_C21H20O12[M + H]+'], ['MetFragSMILES_1_LTS0105577 , YLWQTYZKYGNKPI_structure_C21H20O12[M + H]+']])
# (947, [['MetFragSMILES_3_LTS0081430 , KLZNBERWPKTMAP_structure_C20H30O3[M + H]+'], ['MetFragSMILES_2_LTS0142664 , BYQLYGRDILHOFF_structure_C20H30O3[M + H]+'], ['MetFragSMILES_1_LTS0120852 , GDAJTKZIGQRGOD_structure_C20H30O3[M + H]+']])
# (1121, [['MetFragSMILES_2_LTS0034017 , NFWKVWVWBFBAOV_structure_C20H28O2[M + H]+'], ['MetFragSMILES_3_LTS0151331 , PRZSMDYEVUSNJM_structure_C20H28O2[M + H]+'], ['MetFragSMILES_1_LTS0057168 , IQHBZJPFGJKKJI_structure_C20H28O2[M + H]+']])
# (854, [['MetFragSMILES_1_LTS0088733 , NGBRPGLXCQJIPU_structure_C20H26O2[M + H]+']])
# (759, [['MetFragSMILES_1_LTS0013335 , NYEXXEJYGVAGEE_structure_C19H28O2[M + Na]+'], ['MetFragSMILES_2_LTS0024768 , PIJPSWNOKIPSCP_structure_C19H28O2[M + Na]+']])

# %% [markdown]
# ##### Write results in the resume file.

# %%
 for x in NAP_SIRIUS_sumup:

        list_MF_NAP_SIRIUS=[]
        list_SIRIUS_NAP_SIRIUS=[]
        for i in range(len(x[1])):
            list_MF_NAP_SIRIUS.append(str(x[1][i][0].split(' , ')[0].split('_')[2] + ' MF' + str(x[1][i][0].split(' , ')[0].split('_')[1])))      
            list_SIRIUS_NAP_SIRIUS.append(str(x[1][i][0].split(' , ')[1].split('_')[0] + ' ' +str(x[1][i][0].split(' , ')[1].split('_')[2])))


for x in range(len(NAP_SIRIUS_sumup)):
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(NAP_SIRIUS_sumup[x][0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=None
    

    list_MF_NAP_SIRIUS=[]
    list_SIRIUS_NAP_SIRIUS=[]
    for i in range(len(NAP_SIRIUS_sumup[x][1])):
        list_MF_NAP_SIRIUS.append(str(NAP_SIRIUS_sumup[x][1][i][0].split(' , ')[0].split('_')[2] + ' MF' + str(NAP_SIRIUS_sumup[x][1][i][0].split(' , ')[0].split('_')[1])))      
        list_SIRIUS_NAP_SIRIUS.append(str(NAP_SIRIUS_sumup[x][1][i][0].split(' , ')[1].split('_')[0] + ' ' +str(NAP_SIRIUS_sumup[x][1][i][0].split(' , ')[1].split('_')[2])))
        Dict_sumup['NAP_SU'][numerous]= list_MF_NAP_SIRIUS### 
        Dict_sumup['SIRIUS_SU'][numerous]= list_SIRIUS_NAP_SIRIUS ###
        
        
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
   
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]='GNPS'
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]=None
    Dict_sumup['3rd_Tool_SU'][numerous]=None
    Dict_sumup['Molecular_Name_SU'][numerous]=None
    Dict_sumup['Confidence_Level'][numerous]='11+'

# %% [markdown]
# ##### Apply confidence score = 11+ to all nodes that only have NAP_SIRIUS common annotation, with different FBMN, IIMN candidate

# %%
for x in NAP_SIRIUS_sumup:
    df['All_Tools_confidence'][df['shared name'].tolist().index(x[0])] = '11+'
# Out:
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2850313619.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['All_Tools_confidence'][df['shared name'].tolist().index(x[0])] = '11+' ### au lieu de 4 230814

# %% [markdown]
# #### 1.4 Compare the Mass annotations (FBMN / IIMN, NAP, SIRIUS) to the 13C NMR ones (CaraMel)

# %% [markdown]
# ##### /!\ 13C NMR candidates SMILES must be deposited into a .txt file, one line per candidate (coumpound name and it SMILES), no header /!\

# %%
df_smiles=pd.read_csv(CNMR_candidates_path,sep=' ', header=None)
df_smiles['InchiKey']=None

# %% [markdown]
# #### 1.4.1 Get for each of the candidate its corresponding InChIKey

# %%
for x in range(len(df_smiles[0])):
    m=Chem.MolFromSmiles(df_smiles[1].tolist()[x])
    i=Chem.MolToInchi(m)
    ik=Chem.rdinchi.InchiToInchiKey(i).split('-')[0]
    df_smiles['InchiKey'][x] =ik

df_smiles
# Out:
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#                                     0  \
# 0                            catechin
# 1                         epicatechin
# 2              quercetin-3-rhamnoside
# 3                         acetic_acid
# 4                           astringin
# 5           piceatannol-3-o-glucoside
# 6                 glucosyl-frambinone
# 7                glycerol-monoacetate
# 8                         lavandoside
# 9    glucosyl-trans-paracoumaric-acid
# 10                    larixyl-acetate
# 11                         compound-a
# 12                       ferulic-acid
# 13                          larixinol
# 14                        dianthoside
# 15  arabinosyl-glucosyl-myrtenic-acid
# 16   rhamnosyl-glucosyl-myrtenic-acid
# 17                         oleic-acid
# 18                      linoleic-acid
# 19                       13-epimanool
# 20                    isopimaric-acid
# 21                dehydroabietic-acid
# 22           7-oxodehydroabietic-acid
#
#                                                     1        InchiKey
# 0   C1[C@@H]([C@H](OC2=CC(=CC(=C21)O)O)C3=CC(=C(C=...  PFTAWBLQPZVEMU
# 1   C1[C@H]([C@H](OC2=CC(=CC(=C21)O)O)C3=CC(=C(C=C...  PFTAWBLQPZVEMU
# 2   C[C@@]1([H])[C@@](O)([H])[C@](O)([H])[C@](O)([...  OXGUCUVFOIWWQJ
# 3                                             CC(=O)O  QTBSBXVTEAMEQO
# 4   C1=CC(=C(C=C1/C=C/C2=CC(=CC(=C2)O[C@H]3[C@@H](...  PERPNFLGJXUDDW
# 5   C1=CC(=C(C=C1/C=C/C2=CC(=CC(=C2)O)O)O[C@H]3[C@...  UMGCIIXWEFTPOC
# 6         CC(=O)CCC1=CC=C(C=C1)OC2C(C(C(C(O2)CO)O)O)O  IDONYWHRKBUDOR
# 7                                      CC(=O)OCC(CO)O  KMZHZAAOEWVPSE
# 8   COC1=C(C=CC(=C1)/C=C/C(=O)O)O[C@H]2[C@@H]([C@H...  IEMIRSXOYFWPFD
# 9   C1=CC(=CC=C1/C=C/C(=O)O)O[C@H]2[C@@H]([C@H]([C...  LJFYQZQUAULRDF
# 10   CC(=O)OC1CC(=C)C(C2(C1C(CCC2)(C)C)C)CCC(C)(C=C)O  WCNCDVQMEQJFGH
# 11     OC1=C(CC(O)=O)C(OC(C2=CC=C(O)C=C2)=O)=CC(O)=C1  FARKQCFHLDLVHE
# 12                      COC1=C(C=CC(=C1)/C=C/C(=O)O)O  KSEBMYQBYZTDHS
# 13  C1[C@H]([C@H](OC2=C1C(=CC3=C2[C@]4([C@H](OC5=C...  RNDNBGULZNCSNB
# 14  CC1=C(C(=O)C=CO1)O[C@H]2[C@@H]([C@H]([C@@H]([C...  YGSIRXHFAUFUEJ
# 15  CC1([C@H]2C(C(O[C@H]3[C@@H]([C@H]([C@@H]([C@H]...  CUXTWCNKWNWIEF
# 16  CC1(C)C2C(C(O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C...  XFXXEVLOTVJMBV
# 17                         CCCCCCCC/C=C\CCCCCCCC(=O)O  ZQPPMHVWECSIRJ
# 18                      CCCCC/C=C\C/C=C\CCCCCCCC(=O)O  OYHQOLUKZRVURQ
# 19  C[C@]12CCCC([C@@H]1CCC(=C)[C@@H]2CC[C@@](C)(C=...  CECREIRZLPLYDM
# 20  C[C@@]1(CC[C@H]2C(=CC[C@@H]3[C@@]2(CCC[C@@]3(C...  MXYATHGRPJZBNA
# 21  CC(C)C1=CC2=C(C=C1)[C@]3(CCC[C@@]([C@@H]3CC2)(...  NFWKVWVWBFBAOV
# 22  CC(C)C1=CC2=C(C=C1)[C@]3(CCC[C@@]([C@@H]3CC2=O...  MSWJSDLNPCSSNW

# %% [markdown]
# #### 1.4.2 Compare the features that have GNPS_NAP_SIRIUS common annotations to 13C NMR annotations

# %%
def compare_to_nmr_annotation1(df_smiles, common_sumup):
    list_ID=[]
    if len(common_sumup) == 0:
        print('There was no corresponding feature for this comparison.')
    else:
        
        df_common_sumup =pd.DataFrame(common_sumup)
        df_common_sumup['inchikey']=None
        df_common_sumup['formula']=None
        for x in range(len(df_common_sumup[0])):
            df_common_sumup['inchikey'][x] = df_common_sumup[3][x].split('_')[0]
            df_common_sumup['formula'][x] = df_common_sumup[3][x].split('_')[2]

        for x in df_smiles['InchiKey'].tolist():
            if x in df_common_sumup['inchikey'].tolist():
                txt = df_common_sumup[0].loc[df_common_sumup['inchikey']==x].tolist()[0], df_common_sumup[1].loc[df_common_sumup['inchikey']==x].tolist()[0], str(df_common_sumup[2].loc[df_common_sumup['inchikey']==x].tolist()[0].split('_')[2] + '  MF' + str(df_common_sumup[2].loc[df_common_sumup['inchikey']==x].tolist()[0].split('_')[1]))  , x, df_common_sumup['formula'].loc[df_common_sumup['inchikey']==x].tolist()[0], df_smiles[0][df_smiles['InchiKey'].tolist().index(x)]

                list_ID.append((txt))
        if len(list_ID) == 0 :
            print('No GNPS_NAP_SIRIUS common annotation features  are confirmed by 13C NMR workflow.')
        else:
            print(f'There are {len(list_ID)} features GNPS_NAP_SIRIUS common annotation feature that are confirmed by 13C NMR workflow.' + '\n')
            for x in list_ID:
                print(x)
    return list_ID

# %%
xa=[]
xa = compare_to_nmr_annotation1(df_smiles, common_sumup)
# Out:
# There are 3 features GNPS_NAP_SIRIUS common annotation feature that are confirmed by 13C NMR workflow.
#
# (60, 'CCMSLIB00005742701', 'LTS0265245  MF1', 'PFTAWBLQPZVEMU', 'C15H14O6[M + H]+', 'catechin')
# (60, 'CCMSLIB00005742701', 'LTS0265245  MF1', 'PFTAWBLQPZVEMU', 'C15H14O6[M + H]+', 'catechin')
# (237, 'CCMSLIB00000085852', 'LTS0186298  MF1', 'OXGUCUVFOIWWQJ', 'C21H20O11[M + H]+', 'quercetin-3-rhamnoside')
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\938367055.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_common_sumup['inchikey'][x] = df_common_sumup[3][x].split('_')[0]
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\938367055.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_common_sumup['formula'][x] = df_common_sumup[3][x].split('_')[2]

# %% [markdown]
# #### 1.4.3 Compare the features that only have GNPS_NAP common annotations to 13C NMR annotations

# %%
def compare_to_nmr_annotation2a(df_smiles, common_sumup):
    list_ID=[]
    if len(common_sumup) == 0:
        print('There were no corresponding feature for this comparison.')
    else:
        df_common_sumup =pd.DataFrame(common_sumup)
        df_common_sumup['inchikey']=None
        for x in range(len(df_common_sumup[0])):
            m=Chem.MolFromSmiles(df_common_sumup[3].tolist()[x])
            i=Chem.MolToInchi(m)
            ik=Chem.rdinchi.InchiToInchiKey(i).split('-')[0]
            df_common_sumup['inchikey'][x] = ik

        for x in df_smiles['InchiKey'].tolist():
            if x in df_common_sumup['inchikey'].tolist():
                txt = df_common_sumup[0].loc[df_common_sumup['inchikey']==x].tolist()[0], df_common_sumup[1].loc[df_common_sumup['inchikey']==x].tolist()[0], str(df_common_sumup[2].loc[df_common_sumup['inchikey']==x].tolist()[0].split('_')[2] + '  MF' + str(df_common_sumup[2].loc[df_common_sumup['inchikey']==x].tolist()[0].split('_')[1])), df_smiles[0][df_smiles['InchiKey'].tolist().index(x)]

                list_ID.append((txt))

        if len(list_ID) == 0 :
            print('No GNPS_NAP common annotation features  are confirmed by 13C NMR workflow.')
        else:
            print(f'There are {len(list_ID)} features GNPS_NAP common annotation feature that are confirmed by 13C NMR workflow.' + '\n')
            for x in list_ID:
                print(x)
            
    return list_ID

# %%
xb1=[]
xb1 = compare_to_nmr_annotation2a(df_smiles, GNPS_NAP_common_sumup)
# Out:
# There were no corresponding feature for this comparison.

# %% [markdown]
# #### 1.4.4 Compare the features that only have GNPS_SIRIUS common annotations  to 13C NMR annotations

# %%
def compare_to_nmr_annotation2b(df_smiles, common_sumup):
    list_ID=[]
    if len(common_sumup) == 0:
        print('There were no corresponding feature for this comparison.')
    else:
        df_common_sumup =pd.DataFrame(common_sumup)
        df_common_sumup['inchikey']=None
        df_common_sumup['formula']=None
        for x in range(len(df_common_sumup[0])):
            df_common_sumup['inchikey'][x] = df_common_sumup[2][x].split('_')[0]
            df_common_sumup['formula'][x] = df_common_sumup[2][x].split('_')[2]

        for x in df_smiles['InchiKey'].tolist():
            if x in df_common_sumup['inchikey'].tolist():
                txt = df_common_sumup[0].loc[df_common_sumup['inchikey']==x].tolist()[0], df_common_sumup[1].loc[df_common_sumup['inchikey']==x].tolist()[0], x, df_common_sumup['formula'].loc[df_common_sumup['inchikey']==x].tolist()[0], df_smiles[0][df_smiles['InchiKey'].tolist().index(x)]

                list_ID.append((txt))
        if len(list_ID) == 0 :
            print('There is no matching annotation with 13C NMR.')
        else:
            print(f'There are {len(list_ID)} features GNPS_SIRIUS common annotation feature that are confirmed by 13C NMR workflow.' + '\n')
            for x in list_ID:
                print(x)
    return list_ID

# %%
xb2=[]
xb2 = compare_to_nmr_annotation2b(df_smiles, GNPS_SIRIUS_common_sumup)
# Out:
# There is no matching annotation with 13C NMR.
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1145454546.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_common_sumup['inchikey'][x] = df_common_sumup[2][x].split('_')[0]
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1145454546.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_common_sumup['formula'][x] = df_common_sumup[2][x].split('_')[2]

# %% [markdown]
# #### 1.4.5 Compare the features that only have NAP_SIRIUS common annotations (but with different FBMN, IIMN candidate)  to 13C NMR annotations

# %%
def compare_to_nmr_annotation3a(df_smiles, common_sumup):
    list_ID=[]
    if len(common_sumup) == 0 :
        print('There is no matching annotation with 13C NMR.')
    else:
        df_common_sumup =pd.DataFrame(common_sumup)

        df_common_sumup['inchikey']=None
        df_common_sumup['formula']=None
        df_common_sumup['MF']=None

        for x in range(len(df_common_sumup[0])):
            list_key = []
            list_formula=[]
            list_MF=[]
            for i in range(len(df_common_sumup[1][x])):
                list_key.append(df_common_sumup[1][x][i][0].split(' , ')[1].split('_')[0])
                list_formula.append(df_common_sumup[1][x][i][0].split(' , ')[1].split('_')[2])
                list_MF.append(str(df_common_sumup[1][x][i][0].split(' , ')[0].split('_')[2] + ' MF' + str(df_common_sumup[1][x][i][0].split(' , ')[0].split('_')[1])) )

            df_common_sumup['inchikey'][x] = list_key
            df_common_sumup['formula'][x] = list_formula
            df_common_sumup['MF'][x] = list_MF

            for y in df_smiles['InchiKey'].tolist():
                if y in df_common_sumup['inchikey'][x]:
                    txt = df_common_sumup[0][x], df_common_sumup['MF'][x][df_common_sumup['inchikey'][x].index(y)], y,  df_common_sumup['formula'][x][df_common_sumup['inchikey'][x].index(y)], df_smiles[0][df_smiles['InchiKey'].tolist().index(y)]


                    list_ID.append((txt))
        if len(list_ID) == 0:
            print('There is no matching annotation with 13C NMR.')
        else:
            print(f'There are {len(list_ID)} features NAP_SIRIUS common annotation feature that are confirmed by 13C NMR workflow.' + '\n')
            for x in list_ID:
                print(x)
    return list_ID

# %%
xc1=[]
xc1 = compare_to_nmr_annotation3a(df_smiles, NAP_SIRIUS_sumup)
# Out:
# There are 1 features NAP_SIRIUS common annotation feature that are confirmed by 13C NMR workflow.
#
# (1121, 'LTS0034017 MF2', 'NFWKVWVWBFBAOV', 'C20H28O2[M + H]+', 'dehydroabietic-acid')
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3761614702.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_common_sumup['inchikey'][x] = list_key
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3761614702.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_common_sumup['formula'][x] = list_formula
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3761614702.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_common_sumup['MF'][x] = list_MF

# %% [markdown]
# ## 2. If your data do not contains GNPS annotations through the FBMN and/or IIMN, but at least one MetFrag candidate through NAP, you should run the following cells.
# This will select the corresponding features (PRED value = 2).
#
# **/!\**  The present script is working with **maximum 3 MetFrag candidates** **/!\**
#
# **/!\** Fusion and Consensus candidates will not be considered **/!\**

# %%
df1=df.loc[df['PRED']==2]
df1[['MetFragID1', 'MetFragID2', 'MetFragID3']] = df1['MetFragID'].str.split(',', expand=True)
df1[['MetFragSMILES1', 'MetFragSMILES2', 'MetFragSMILES3']] = df1['MetFragSMILES'].str.split(',', expand=True)
# Out:
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1506672247.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['MetFragID1', 'MetFragID2', 'MetFragID3']] = df1['MetFragID'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1506672247.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['MetFragID1', 'MetFragID2', 'MetFragID3']] = df1['MetFragID'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1506672247.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['MetFragID1', 'MetFragID2', 'MetFragID3']] = df1['MetFragID'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1506672247.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['MetFragSMILES1', 'MetFragSMILES2', 'MetFragSMILES3']] = df1['MetFragSMILES'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1506672247.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['MetFragSMILES1', 'MetFragSMILES2', 'MetFragSMILES3']] = df1['MetFragSMILES'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1506672247.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['MetFragSMILES1', 'MetFragSMILES2', 'MetFragSMILES3']] = df1['MetFragSMILES'].str.split(',', expand=True)

# %% [markdown]
# ##### Get the list of untreated nodes

# %%
not_common=[x for x in df1['shared name'].tolist() if x not in all_common ]
not_common = [x for x in not_common if math.isnan(x) == False]
print(f'There are still {len(not_common)} features to treat now.')
# Out:
# There are still 150 features to treat now.

# %% [markdown]
# If you want to vizualize the features, run the cell bellow

# %%
for x in sorted(not_common):
    try: 
        print(f'Feature n {int(x)}')
    except:
        continue
# Out:
# Feature n 5
# Feature n 30
# Feature n 81
# Feature n 102
# Feature n 113
# Feature n 124
# Feature n 129
# Feature n 147
# Feature n 158
# Feature n 165
# Feature n 230
# Feature n 276
# Feature n 279
# Feature n 284
# Feature n 288
# Feature n 318
# Feature n 336
# Feature n 420
# Feature n 423
# Feature n 434
# Feature n 450
# Feature n 485
# Feature n 501
# Feature n 520
# Feature n 529
# Feature n 536
# Feature n 538
# Feature n 541
# Feature n 542
# Feature n 543
# Feature n 552
# Feature n 555
# Feature n 559
# Feature n 561
# Feature n 565
# Feature n 571
# Feature n 572
# Feature n 586
# Feature n 590
# Feature n 592
# Feature n 604
# Feature n 612
# Feature n 615
# Feature n 616
# Feature n 619
# Feature n 624
# Feature n 649
# Feature n 655
# Feature n 657
# Feature n 665
# Feature n 673
# Feature n 674
# Feature n 688
# Feature n 690
# Feature n 691
# Feature n 706
# Feature n 716
# Feature n 717
# Feature n 748
# Feature n 754
# Feature n 760
# Feature n 787
# Feature n 798
# Feature n 816
# Feature n 821
# Feature n 828
# Feature n 849
# Feature n 871
# Feature n 872
# Feature n 873
# Feature n 888
# Feature n 894
# Feature n 896
# Feature n 904
# Feature n 909
# Feature n 913
# Feature n 931
# Feature n 940
# Feature n 942
# Feature n 944
# Feature n 945
# Feature n 948
# Feature n 949
# Feature n 956
# Feature n 961
# Feature n 973
# Feature n 983
# Feature n 993
# Feature n 998
# Feature n 999
# Feature n 1002
# Feature n 1003
# Feature n 1006
# Feature n 1013
# Feature n 1023
# Feature n 1026
# Feature n 1029
# Feature n 1030
# Feature n 1031
# Feature n 1041
# Feature n 1043
# Feature n 1052
# Feature n 1068
# Feature n 1080
# Feature n 1089
# Feature n 1092
# Feature n 1111
# Feature n 1116
# Feature n 1127
# Feature n 1136
# Feature n 1183
# Feature n 1185
# Feature n 1189
# Feature n 1219
# Feature n 1249
# Feature n 1250
# Feature n 1267
# Feature n 1272
# Feature n 1288
# Feature n 1305
# Feature n 1307
# Feature n 1309
# Feature n 1316
# Feature n 1322
# Feature n 1323
# Feature n 1332
# Feature n 1345
# Feature n 1347
# Feature n 1349
# Feature n 1356
# Feature n 1357
# Feature n 1380
# Feature n 1425
# Feature n 1426
# Feature n 1447
# Feature n 1449
# Feature n 1454
# Feature n 1470
# Feature n 1474
# Feature n 1476
# Feature n 1606
# Feature n 1645
# Feature n 1646
# Feature n 1772
# Feature n 1821
# Feature n 1867
# Feature n 1914
# Feature n 1969
# Feature n 2139
# Feature n 2479

# %% [markdown]
# #### 2.1 Get the informations for the features that only have NAP_SIRIUS common annotation, without any GNPS annotation.

# %%
list_ID2=[]
list_ID3=[]
list_ID4=[]
for x in not_common:  

    ik1,ik2,ik3='', '',''
    if df1['MetFragSMILES1'].tolist()[df1['shared name'].tolist().index(x)] != None:
        try:
             
            m1=Chem.MolFromSmiles(df1['MetFragSMILES1'].tolist()[df1['shared name'].tolist().index(x)])
            i1=Chem.MolToInchi(m1)
            ik1=Chem.rdinchi.InchiToInchiKey(i1).split('-')[0]
            

        except:
            continue
        
            
    if df1['MetFragSMILES2'].tolist()[df1['shared name'].tolist().index(x)]!= None:   
        try:
            
            m2=Chem.MolFromSmiles(df1['MetFragSMILES2'].tolist()[df1['shared name'].tolist().index(x)])
            i2=Chem.MolToInchi(m2)
            ik2=Chem.rdinchi.InchiToInchiKey(i2).split('-')[0]
            

            
        except:
            continue
        
        
    if df1['MetFragSMILES3'].tolist()[df1['shared name'].tolist().index(x)]!= None:   
        try:
             
            m3=Chem.MolFromSmiles(df1['MetFragSMILES3'].tolist()[df1['shared name'].tolist().index(x)])
            i3=Chem.MolToInchi(m3)
            ik3=Chem.rdinchi.InchiToInchiKey(i3).split('-')[0]
            

        except:
            continue
    list_ID3.append(x)
    list_ID2.append([ik1, ik2, ik3])
    
    LMF1 = df1['MetFragID1'].tolist()[df1['shared name'].tolist().index(x)]
    LMF2=df1['MetFragID2'].tolist()[df1['shared name'].tolist().index(x)]
    LMF3=df1['MetFragID3'].tolist()[df1['shared name'].tolist().index(x)]
    list_ID4.append([LMF1, LMF2, LMF3])
# Out:
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo
#
# [16:42:22] WARNING: Omitted undefined stereo

# %%
NAP_SIRIUS_sumup=[]
list_sirius_inchikey3=[]
if len(list_ID3) == 0:
    print('There is no feature for the comparison.')
else:
    for ID in list_ID3: 
        ID=int(ID)

        filein =[x for x in list_folder if  str('_' + str(ID)) == x[-len(str('_' + str(ID))):]]
        if len(filein)!=0:
            os.chmod(filein[0], stat.S_IROTH)

            if os.path.exists(filein[0]+'/structure_candidates.tsv'):
                df_sirius_formula = pd.read_csv(filein[0]+'/structure_candidates.tsv', sep='\t')

                aa=[]
                for z in range(len(df_sirius_formula['InChIkey2D'].tolist())):
                    if df_sirius_formula['InChIkey2D'].tolist()[z] in list_ID2[list_ID3.index(ID)]:
                        aa1 = (str('MetFragSMILES_' + str(list_ID2[list_ID3.index(ID)].index(df_sirius_formula['InChIkey2D'].tolist()[z])+1) + '_' +  list_ID4[list_ID3.index(ID)][list_ID2[list_ID3.index(ID)].index(df_sirius_formula['InChIkey2D'].tolist()[z])] +' , '+ str(df_sirius_formula['InChIkey2D'].tolist()[z]) + '_structure_' + str(df_sirius_formula['molecularFormula'].tolist()[z]) + df_sirius_formula['adduct'].tolist()[z] ))

                        list_sirius_inchikey3.append(ID)
                        aa.append([aa1])
                    else:
                        aa1=''


                if len(aa) !=0:
                    NAP_SIRIUS_sumup.append((ID, aa))

    if len(NAP_SIRIUS_sumup) == 0 :
        print('There is no common annotation between NAP and SIRIUS workflows for features without any GNPS candiddate.')
    else:
        print(f'There are {len(NAP_SIRIUS_sumup)} features without any GNPS candidate that have common annotation between NAP et SIRIUS workflow.' + '\n')
        for x in NAP_SIRIUS_sumup:
            print(x)
# Out:
# There are 109 features without any GNPS candidate that have common annotation between NAP et SIRIUS workflow.
#
# (501, [['MetFragSMILES_1_LTS0013335 , NYEXXEJYGVAGEE_structure_C19H28O2[M + H]+'], ['MetFragSMILES_2_LTS0024768 , PIJPSWNOKIPSCP_structure_C19H28O2[M + H]+']])
# (1111, [['MetFragSMILES_1_LTS0064099 , YCLCHPWRGSDZKL_structure_C20H28O[M + H]+'], ['MetFragSMILES_2_LTS0035059 , ISHVJVXYPLFKAL_structure_C20H28O[M + H]+']])
# (1006, [['MetFragSMILES_1_LTS0254324 , MXPXAZNVQUWDFH_structure_C20H26O4[M + H]+'], ['MetFragSMILES_3_LTS0046848 , MXCOJKLBLFWFNI_structure_C20H26O4[M + H]+'], ['MetFragSMILES_2_LTS0002654 , PKAIECBWQZFYRP_structure_C20H26O4[M + H]+']])
# (565, [['MetFragSMILES_1_LTS0171116 , SGCHZBKQDFNHSL_structure_C19H26O3[M + H]+']])
# (619, [['MetFragSMILES_1_LTS0088733 , NGBRPGLXCQJIPU_structure_C20H26O2[M + H]+']])
# (1272, [['MetFragSMILES_2_LTS0034017 , NFWKVWVWBFBAOV_structure_C20H28O2[M + H]+'], ['MetFragSMILES_3_LTS0151331 , PRZSMDYEVUSNJM_structure_C20H28O2[M + H]+'], ['MetFragSMILES_1_LTS0057168 , IQHBZJPFGJKKJI_structure_C20H28O2[M + H]+']])
# (873, [['MetFragSMILES_1_LTS0092634 , ZSHVSBCOLVBOLB_structure_C24H32O5[M + H]+']])
# (828, [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']])
# (1068, [['MetFragSMILES_2_LTS0201039 , VOYZLKWKVLYJHD_structure_C30H46O3[M + H]+'], ['MetFragSMILES_1_LTS0049064 , DKGGOTRAZUOHPG_structure_C30H46O3[M + H]+'], ['MetFragSMILES_3_LTS0004634 , GVVASFXQODQNLW_structure_C30H46O3[M + H]+']])
# (1080, [['MetFragSMILES_1_LTS0002592 , SIYBXEYFWKPLJC_structure_C28H46O3[M + H]+']])
# (896, [['MetFragSMILES_1_LTS0184224 , CYOURYOZWLIJFB_structure_C20H32O[M + H]+'], ['MetFragSMILES_2_LTS0185646 , PMRGRURZTGRVDP_structure_C20H32O[M + H]+'], ['MetFragSMILES_3_LTS0150156 , GQRUHVMVWNKUFW_structure_C20H32O[M + H]+']])
# (657, [['MetFragSMILES_1_LTS0108097 , PTQFIYQNKVSVGM_structure_C19H26O2[M + H]+']])
# (787, [['MetFragSMILES_3_LTS0046650 , MLBYBBUZURKHAW_structure_C20H30O2[M + H]+'], ['MetFragSMILES_1_LTS0203405 , FKCPLBHSZGVMNG_structure_C20H30O2[M + H]+'], ['MetFragSMILES_2_LTS0243815 , PORHOKHIMOFMMH_structure_C20H30O2[M + H]+']])
# (590, [['MetFragSMILES_1_LTS0108097 , PTQFIYQNKVSVGM_structure_C19H26O2[M + H]+']])
# (1454, [['MetFragSMILES_1_LTS0270354 , AOSOLLDONLOYAH_structure_C29H48O2[M + Na]+'], ['MetFragSMILES_2_LTS0212919 , HMMVBUVVQLUGQA_structure_C29H48O2[M + Na]+']])
# (529, [['MetFragSMILES_1_LTS0194549 , QUAMTGJKVDWJEQ_structure_C21H26O3[M + H]+']])
# (552, [['MetFragSMILES_2_LTS0135808 , QMSWKASVXHXIKB_structure_C20H28O5[M + Na]+'], ['MetFragSMILES_1_LTS0083162 , CKMAUJLOUQNVRZ_structure_C20H28O5[M + Na]+'], ['MetFragSMILES_3_LTS0022360 , CFJWRSMUQIAHTA_structure_C20H28O5[M + Na]+']])
# (561, [['MetFragSMILES_2_LTS0056945 , CUXCAMYFFUWHQV_structure_C20H28O4[M + H]+'], ['MetFragSMILES_3_LTS0027960 , ALGYTGOYQATWBA_structure_C20H28O4[M + H]+'], ['MetFragSMILES_1_LTS0255603 , HEIKHXMGSYQVGA_structure_C20H28O4[M + H]+']])
# (1305, [['MetFragSMILES_3_LTS0079225 , WTFWUWLORKLWCJ_structure_C20H34O2[M + Na]+'], ['MetFragSMILES_2_LTS0165489 , BSKNIQVPQSFUSP_structure_C20H34O2[M + Na]+']])
# (999, [['MetFragSMILES_3_LTS0114300 , MDWQSNIQXHNTCK_structure_C20H30O[M + H]+'], ['MetFragSMILES_1_LTS0000316 , WSKGRAGZAQRSED_structure_C20H30O[M + H]+'], ['MetFragSMILES_2_LTS0149356 , JMYBTVXXLMTVKS_structure_C20H30O[M + H]+']])
# (586, [['MetFragSMILES_2_LTS0000316 , WSKGRAGZAQRSED_structure_C20H30O[M + H]+'], ['MetFragSMILES_1_LTS0149356 , JMYBTVXXLMTVKS_structure_C20H30O[M + H]+'], ['MetFragSMILES_3_LTS0127038 , CUFRQYVSJJHEKT_structure_C20H30O[M + H]+']])
# (1347, [['MetFragSMILES_1_LTS0041481 , KUMASSYJGMPIHK_structure_C31H50O4[M + H]+']])
# (336, [['MetFragSMILES_1_LTS0269975 , RNDNBGULZNCSNB_structure_C30H22O10[M + H]+']])
# (691, [['MetFragSMILES_2_LTS0184224 , CYOURYOZWLIJFB_structure_C20H32O[M + H]+'], ['MetFragSMILES_3_LTS0185646 , PMRGRURZTGRVDP_structure_C20H32O[M + H]+'], ['MetFragSMILES_1_LTS0150156 , GQRUHVMVWNKUFW_structure_C20H32O[M + H]+']])
# (821, [['MetFragSMILES_1_LTS0108097 , PTQFIYQNKVSVGM_structure_C19H26O2[M + Na]+']])
# (1476, [['MetFragSMILES_1_LTS0064099 , YCLCHPWRGSDZKL_structure_C20H28O[M + H]+'], ['MetFragSMILES_2_LTS0035059 , ISHVJVXYPLFKAL_structure_C20H28O[M + H]+']])
# (674, [['MetFragSMILES_2_LTS0034017 , NFWKVWVWBFBAOV_structure_C20H28O2[M + H]+'], ['MetFragSMILES_3_LTS0151331 , PRZSMDYEVUSNJM_structure_C20H28O2[M + H]+'], ['MetFragSMILES_1_LTS0057168 , IQHBZJPFGJKKJI_structure_C20H28O2[M + H]+']])
# (1322, [['MetFragSMILES_3_LTS0220552 , IQVKGPHVUDYNPT_structure_C26H40O6[M + H]+'], ['MetFragSMILES_2_LTS0201681 , NASOHMFLGZORKU_structure_C26H40O6[M + H]+'], ['MetFragSMILES_1_LTS0034815 , AHBQIYSLXQMIEO_structure_C26H40O6[M + H]+']])
# (1356, [['MetFragSMILES_1_LTS0087433 , SKHNEXWRHKHJFZ_structure_C29H44O2[M + H]+']])
# (230, [['MetFragSMILES_1_LTS0044016 , OTWLSQPCSOEBAY_structure_C20H18O7[M + Na]+']])
# (948, [['MetFragSMILES_3_LTS0114300 , MDWQSNIQXHNTCK_structure_C20H30O[M + H]+'], ['MetFragSMILES_1_LTS0000316 , WSKGRAGZAQRSED_structure_C20H30O[M + H]+'], ['MetFragSMILES_2_LTS0149356 , JMYBTVXXLMTVKS_structure_C20H30O[M + H]+']])
# (536, [['MetFragSMILES_1_LTS0232556 , VUSNLFYUMKLEAV_structure_C19H24O3[M + H]+'], ['MetFragSMILES_2_LTS0105708 , QDCGSCBAIQIGDY_structure_C19H24O3[M + H]+']])
# (1127, [['MetFragSMILES_2_LTS0055409 , CDCKBLNAQWOFID_structure_C30H46O2[M + H]+'], ['MetFragSMILES_3_LTS0106688 , TWBVZVAEDWRAJO_structure_C30H46O2[M + H]+'], ['MetFragSMILES_1_LTS0041018 , VZPCWSKCBLYYSO_structure_C30H46O2[M + H]+']])
# (1089, [['MetFragSMILES_1_LTS0160094 , VZCCETWTMQHEPK_structure_C18H30O2[M + H]+'], ['MetFragSMILES_2_LTS0132789 , DTOSIQBPPRVQHS_structure_C18H30O2[M + H]+'], ['MetFragSMILES_3_LTS0214201 , HXQHFNIKBKZGRP_structure_C18H30O2[M + H]+']])
# (572, [['MetFragSMILES_1_LTS0255421 , ROGUIJKVZZROIQ_structure_C20H24O5[M + H]+']])
# (909, [['MetFragSMILES_1_LTS0013335 , NYEXXEJYGVAGEE_structure_C19H28O2[M + H]+'], ['MetFragSMILES_2_LTS0024768 , PIJPSWNOKIPSCP_structure_C19H28O2[M + H]+']])
# (1345, [['MetFragSMILES_3_LTS0002171 , ABPDEYSUVLXYCB_structure_C31H48O4[M + H]+'], ['MetFragSMILES_2_LTS0037468 , BGBKLMBLKNDJMK_structure_C31H48O4[M + H]+'], ['MetFragSMILES_1_LTS0022895 , IIPIWCJQGIFRHH_structure_C31H48O4[M + H]+']])
# (1002, [['MetFragSMILES_1_LTS0002592 , SIYBXEYFWKPLJC_structure_C28H46O3[M + H]+']])
# (993, [['MetFragSMILES_1_LTS0088733 , NGBRPGLXCQJIPU_structure_C20H26O2[M + H]+']])
# (1023, [['MetFragSMILES_2_LTS0240388 , RGXBCSRGWBMBCF_structure_C30H46O4[M + H]+'], ['MetFragSMILES_1_LTS0160555 , UPHZQTDFAGIZQK_structure_C30H46O4[M + H]+'], ['MetFragSMILES_3_LTS0266507 , VGVAABHRCNAZRM_structure_C30H46O4[M + H]+']])
# (1969, [['MetFragSMILES_2_LTS0212919 , HMMVBUVVQLUGQA_structure_C29H48O2[M + H]+'], ['MetFragSMILES_1_LTS0270354 , AOSOLLDONLOYAH_structure_C29H48O2[M + H]+']])
# (1380, [['MetFragSMILES_1_LTS0013015 , JWBQJSCILWCBJO_structure_C30H44O3[M + H]+']])
# (165, [['MetFragSMILES_2_LTS0264219 , BDMACDVLTOBWFC_structure_C30H22O12[M + H]+'], ['MetFragSMILES_1_LTS0157787 , KRGQPZUWMNJLOQ_structure_C30H22O12[M + H]+']])
# (748, [['MetFragSMILES_1_LTS0013335 , NYEXXEJYGVAGEE_structure_C19H28O2[M + H]+'], ['MetFragSMILES_2_LTS0024768 , PIJPSWNOKIPSCP_structure_C19H28O2[M + H]+']])
# (276, [['MetFragSMILES_1_LTS0269975 , RNDNBGULZNCSNB_structure_C30H22O10[M + H]+']])
# (1136, [['MetFragSMILES_1_LTS0013015 , JWBQJSCILWCBJO_structure_C30H44O3[M + H]+']])
# (1250, [['MetFragSMILES_1_LTS0054271 , ILQLITDRYFHAGM_structure_C20H28O3[M + H]+'], ['MetFragSMILES_3_LTS0093361 , GPFVBJYXFRIOFB_structure_C20H28O3[M + H]+'], ['MetFragSMILES_2_LTS0087280 , AYDJDNNMKHXZOQ_structure_C20H28O3[M + H]+']])
# (1323, [['MetFragSMILES_3_LTS0079225 , WTFWUWLORKLWCJ_structure_C20H34O2[M + Na]+'], ['MetFragSMILES_2_LTS0165489 , BSKNIQVPQSFUSP_structure_C20H34O2[M + Na]+']])
# (284, [['MetFragSMILES_2_LTS0214803 , VRXLDKQKMDSSHS_structure_C30H22O11[M + H]+'], ['MetFragSMILES_1_LTS0192920 , OAWGSMCKVUHHTO_structure_C30H22O11[M + H]+']])
# (288, [['MetFragSMILES_1_LTS0107505 , IZQSVPBOUDKVDZ_structure_C16H12O7[M + H]+'], ['MetFragSMILES_2_LTS0209810 , JGUZGNYPMHHYRK_structure_C16H12O7[M + H]+']])
# (649, [['MetFragSMILES_1_LTS0013335 , NYEXXEJYGVAGEE_structure_C19H28O2[M + H]+'], ['MetFragSMILES_2_LTS0024768 , PIJPSWNOKIPSCP_structure_C19H28O2[M + H]+']])
# (1425, [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']])
# (1349, [['MetFragSMILES_2_LTS0248187 , QMTZBWPBIQZLBJ_structure_C21H30O3[M + H]+'], ['MetFragSMILES_1_LTS0257851 , QBAITYMIZWFOLG_structure_C21H30O3[M + H]+'], ['MetFragSMILES_3_LTS0067008 , IGUDTNVZIOWVIV_structure_C21H30O3[M + H]+']])
# (945, [['MetFragSMILES_2_LTS0132789 , DTOSIQBPPRVQHS_structure_C18H30O2[M + H]+'], ['MetFragSMILES_1_LTS0160094 , VZCCETWTMQHEPK_structure_C18H30O2[M + H]+'], ['MetFragSMILES_3_LTS0214201 , HXQHFNIKBKZGRP_structure_C18H30O2[M + H]+']])
# (1821, [['MetFragSMILES_1_LTS0002592 , SIYBXEYFWKPLJC_structure_C28H46O3[M + Na]+']])
# (1316, [['MetFragSMILES_1_LTS0155650 , FITFAFMCWGCVDQ_structure_C19H24O[M + H]+']])
# (1288, [['MetFragSMILES_1_LTS0054271 , ILQLITDRYFHAGM_structure_C20H28O3[M + H]+'], ['MetFragSMILES_2_LTS0087280 , AYDJDNNMKHXZOQ_structure_C20H28O3[M + H]+'], ['MetFragSMILES_3_LTS0093361 , GPFVBJYXFRIOFB_structure_C20H28O3[M + H]+']])
# (1332, [['MetFragSMILES_2_LTS0248187 , QMTZBWPBIQZLBJ_structure_C21H30O3[M + H]+'], ['MetFragSMILES_1_LTS0257851 , QBAITYMIZWFOLG_structure_C21H30O3[M + H]+'], ['MetFragSMILES_3_LTS0067008 , IGUDTNVZIOWVIV_structure_C21H30O3[M + H]+']])
# (2139, [['MetFragSMILES_1_LTS0212919 , HMMVBUVVQLUGQA_structure_C29H48O2[M + H]+'], ['MetFragSMILES_2_LTS0270354 , AOSOLLDONLOYAH_structure_C29H48O2[M + H]+']])
# (690, [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']])
# (604, [['MetFragSMILES_1_LTS0013335 , NYEXXEJYGVAGEE_structure_C19H28O2[M + H]+'], ['MetFragSMILES_2_LTS0024768 , PIJPSWNOKIPSCP_structure_C19H28O2[M + H]+']])
# (1003, [['MetFragSMILES_1_LTS0220552 , IQVKGPHVUDYNPT_structure_C26H40O6[M + H]+'], ['MetFragSMILES_2_LTS0201681 , NASOHMFLGZORKU_structure_C26H40O6[M + H]+'], ['MetFragSMILES_3_LTS0034815 , AHBQIYSLXQMIEO_structure_C26H40O6[M + H]+']])
# (1357, [['MetFragSMILES_2_LTS0061235 , KMEQUVNVNHTHSM_structure_C23H36O4[M + H]+'], ['MetFragSMILES_3_LTS0069487 , LODVZNAZFNRTCG_structure_C23H36O4[M + H]+'], ['MetFragSMILES_1_LTS0196897 , AORYFYLFZDBOMS_structure_C23H36O4[M + H]+']])
# (1013, [['MetFragSMILES_1_LTS0049703 , YBQWVVDWBNHYPN_structure_C31H48O6[M + Na]+']])
# (754, [['MetFragSMILES_1_LTS0088733 , NGBRPGLXCQJIPU_structure_C20H26O2[M + Na]+']])
# (542, [['MetFragSMILES_1_LTS0064099 , YCLCHPWRGSDZKL_structure_C20H28O[M + H]+'], ['MetFragSMILES_2_LTS0035059 , ISHVJVXYPLFKAL_structure_C20H28O[M + H]+']])
# (1426, [['MetFragSMILES_1_LTS0019867 , JEOZUAHPKAVXSF_structure_C20H32O[M + H]+'], ['MetFragSMILES_3_LTS0102281 , DUEINKIQNGZKPL_structure_C20H32O[M + H]+'], ['MetFragSMILES_2_LTS0109755 , ATQOOBSXQVRQPY_structure_C20H32O[M + H]+']])
# (1470, [['MetFragSMILES_2_LTS0061235 , KMEQUVNVNHTHSM_structure_C23H36O4[M + Na]+'], ['MetFragSMILES_1_LTS0196897 , AORYFYLFZDBOMS_structure_C23H36O4[M + Na]+'], ['MetFragSMILES_3_LTS0069487 , LODVZNAZFNRTCG_structure_C23H36O4[M + Na]+']])
# (688, [['MetFragSMILES_1_LTS0048384 , JXHQWTYFUSHCGX_structure_C19H28O4[M + H]+'], ['MetFragSMILES_2_LTS0266553 , FZMONKRUPXQHKO_structure_C19H28O4[M + H]+']])
# (1249, [['MetFragSMILES_1_LTS0080951 , PGZCJOPTDHWYES_structure_C21H30O2[M + H]+']])
# (1267, [['MetFragSMILES_1_LTS0224467 , NFRXSIOHGADFRG_structure_C30H48O[M + H]+']])
# (129, [['MetFragSMILES_1_LTS0094372 , CDRPUGZCRXZLFL_structure_C14H12O4[M + H]+']])
# (555, [['MetFragSMILES_3_LTS0046650 , MLBYBBUZURKHAW_structure_C20H30O2[M + H]+'], ['MetFragSMILES_1_LTS0203405 , FKCPLBHSZGVMNG_structure_C20H30O2[M + H]+'], ['MetFragSMILES_2_LTS0243815 , PORHOKHIMOFMMH_structure_C20H30O2[M + H]+']])
# (543, [['MetFragSMILES_2_LTS0046848 , MXCOJKLBLFWFNI_structure_C20H26O4[M + H]+'], ['MetFragSMILES_1_LTS0254324 , MXPXAZNVQUWDFH_structure_C20H26O4[M + H]+'], ['MetFragSMILES_3_LTS0002654 , PKAIECBWQZFYRP_structure_C20H26O4[M + H]+']])
# (1185, [['MetFragSMILES_1_LTS0180660 , AXKQOCLPWRXCRI_structure_C20H26O3[M + H]+'], ['MetFragSMILES_2_LTS0229171 , MSWJSDLNPCSSNW_structure_C20H26O3[M + H]+'], ['MetFragSMILES_3_LTS0074326 , ISECDNAMJMNAHZ_structure_C20H26O3[M + H]+']])
# (944, [['MetFragSMILES_1_LTS0064099 , YCLCHPWRGSDZKL_structure_C20H28O[M + H]+'], ['MetFragSMILES_2_LTS0035059 , ISHVJVXYPLFKAL_structure_C20H28O[M + H]+']])
# (423, [['MetFragSMILES_1_LTS0171116 , SGCHZBKQDFNHSL_structure_C19H26O3[M + H]+']])
# (1474, [['MetFragSMILES_1_LTS0160094 , VZCCETWTMQHEPK_structure_C18H30O2[M + H]+'], ['MetFragSMILES_2_LTS0214201 , HXQHFNIKBKZGRP_structure_C18H30O2[M + H]+'], ['MetFragSMILES_3_LTS0132789 , DTOSIQBPPRVQHS_structure_C18H30O2[M + H]+']])
# (1307, [['MetFragSMILES_2_LTS0201039 , VOYZLKWKVLYJHD_structure_C30H46O3[M + H]+'], ['MetFragSMILES_1_LTS0049064 , DKGGOTRAZUOHPG_structure_C30H46O3[M + H]+'], ['MetFragSMILES_3_LTS0004634 , GVVASFXQODQNLW_structure_C30H46O3[M + H]+']])
# (541, [['MetFragSMILES_1_LTS0083733 , DWHTYLMRWXUGJL_structure_C17H22O3[M + Na]+']])
# (956, [['MetFragSMILES_3_LTS0046650 , MLBYBBUZURKHAW_structure_C20H30O2[M + Na]+'], ['MetFragSMILES_1_LTS0203405 , FKCPLBHSZGVMNG_structure_C20H30O2[M + Na]+'], ['MetFragSMILES_2_LTS0243815 , PORHOKHIMOFMMH_structure_C20H30O2[M + Na]+']])
# (1867, [['MetFragSMILES_2_LTS0240596 , QEMIUYHLZNNZQN_structure_C32H50O4[M + H]+'], ['MetFragSMILES_1_LTS0220282 , NWUYJACIJALREE_structure_C32H50O4[M + H]+']])
# (998, [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']])
# (1219, [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']])
# (717, [['MetFragSMILES_3_LTS0114300 , MDWQSNIQXHNTCK_structure_C20H30O[M + H]+'], ['MetFragSMILES_2_LTS0000316 , WSKGRAGZAQRSED_structure_C20H30O[M + H]+'], ['MetFragSMILES_1_LTS0149356 , JMYBTVXXLMTVKS_structure_C20H30O[M + H]+']])
# (612, [['MetFragSMILES_1_LTS0266553 , FZMONKRUPXQHKO_structure_C19H28O4[M + H]+'], ['MetFragSMILES_2_LTS0048384 , JXHQWTYFUSHCGX_structure_C19H28O4[M + H]+']])
# (1447, [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']])
# (2479, [['MetFragSMILES_3_LTS0029311 , HCXVJBMSMIARIN_structure_C29H48O[M + H]+'], ['MetFragSMILES_2_LTS0214714 , KYOFIJXMVNQYFC_structure_C29H48O[M + H]+'], ['MetFragSMILES_1_LTS0003409 , RUVUHIUYGJBLGI_structure_C29H48O[M + H]+']])
# (1189, [['MetFragSMILES_1_LTS0064099 , YCLCHPWRGSDZKL_structure_C20H28O[M + H]+'], ['MetFragSMILES_2_LTS0035059 , ISHVJVXYPLFKAL_structure_C20H28O[M + H]+']])
# (904, [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']])
# (1606, [['MetFragSMILES_3_LTS0258577 , VYWGLUCGRVXWKB_structure_C20H32[M + H]+'], ['MetFragSMILES_2_LTS0107403 , DMHADBQKVWXPPM_structure_C20H32[M + H]+'], ['MetFragSMILES_1_LTS0048295 , BBPXZLJCPUPNGH_structure_C20H32[M + H]+']])
# (849, [['MetFragSMILES_3_LTS0034017 , NFWKVWVWBFBAOV_structure_C20H28O2[M + H]+'], ['MetFragSMILES_2_LTS0151331 , PRZSMDYEVUSNJM_structure_C20H28O2[M + H]+'], ['MetFragSMILES_1_LTS0057168 , IQHBZJPFGJKKJI_structure_C20H28O2[M + H]+']])
# (760, [['MetFragSMILES_2_LTS0064099 , YCLCHPWRGSDZKL_structure_C20H28O[M + H]+'], ['MetFragSMILES_1_LTS0035059 , ISHVJVXYPLFKAL_structure_C20H28O[M + H]+']])
# (931, [['MetFragSMILES_1_LTS0241153 , YZXBAPSDXZZRGB_structure_C20H32O2[M + H]+'], ['MetFragSMILES_3_LTS0068275 , JFQBNOIJWROZGE_structure_C20H32O2[M + H]+'], ['MetFragSMILES_2_LTS0158625 , OJSKJQFODPKTBT_structure_C20H32O2[M + H]+']])
# (158, [['MetFragSMILES_1_LTS0094372 , CDRPUGZCRXZLFL_structure_C14H12O4[M + H]+']])
# (949, [['MetFragSMILES_1_LTS0118921 , SOJWLJKPIIODOH_structure_C19H28O[M + H]+']])
# (1914, [['MetFragSMILES_2_LTS0212919 , HMMVBUVVQLUGQA_structure_C29H48O2[M + H]+'], ['MetFragSMILES_1_LTS0270354 , AOSOLLDONLOYAH_structure_C29H48O2[M + H]+']])
# (1092, [['MetFragSMILES_2_LTS0248187 , QMTZBWPBIQZLBJ_structure_C21H30O3[M + H]+'], ['MetFragSMILES_1_LTS0067008 , IGUDTNVZIOWVIV_structure_C21H30O3[M + H]+'], ['MetFragSMILES_3_LTS0257851 , QBAITYMIZWFOLG_structure_C21H30O3[M + H]+']])
# (1449, [['MetFragSMILES_1_LTS0019867 , JEOZUAHPKAVXSF_structure_C20H32O[M + H]+'], ['MetFragSMILES_3_LTS0102281 , DUEINKIQNGZKPL_structure_C20H32O[M + H]+'], ['MetFragSMILES_2_LTS0109755 , ATQOOBSXQVRQPY_structure_C20H32O[M + H]+']])
# (665, [['MetFragSMILES_1_LTS0155650 , FITFAFMCWGCVDQ_structure_C19H24O[M + H]+']])
# (1030, [['MetFragSMILES_1_LTS0013335 , NYEXXEJYGVAGEE_structure_C19H28O2[M + Na]+'], ['MetFragSMILES_2_LTS0024768 , PIJPSWNOKIPSCP_structure_C19H28O2[M + Na]+']])
# (1026, [['MetFragSMILES_1_LTS0088733 , NGBRPGLXCQJIPU_structure_C20H26O2[M + H]+']])
# (279, [['MetFragSMILES_1_LTS0107505 , IZQSVPBOUDKVDZ_structure_C16H12O7[M + H]+'], ['MetFragSMILES_2_LTS0209810 , JGUZGNYPMHHYRK_structure_C16H12O7[M + H]+']])
# (961, [['MetFragSMILES_1_LTS0155650 , FITFAFMCWGCVDQ_structure_C19H24O[M + H]+']])
# (616, [['MetFragSMILES_1_LTS0171116 , SGCHZBKQDFNHSL_structure_C19H26O3[M + Na]+']])
# (888, [['MetFragSMILES_1_LTS0079469 , UKOKENMLXFNPEJ_structure_C20H22O3[M + H]+']])
# (318, [['MetFragSMILES_2_LTS0214803 , VRXLDKQKMDSSHS_structure_C30H22O11[M + H]+'], ['MetFragSMILES_1_LTS0192920 , OAWGSMCKVUHHTO_structure_C30H22O11[M + H]+']])
# (716, [['MetFragSMILES_2_LTS0013015 , JWBQJSCILWCBJO_structure_C30H44O3[M + H]+']])
# (147, [['MetFragSMILES_1_LTS0203074 , RSYUFYQTACJFML_structure_C15H14O5[M + H]+']])

# %% [markdown]
# ##### Get the detail result for common NAP_SIRIUS annotations features
# ##### (Feature ID, matching MetFrag position + LOTUS_ID, InChIKey + chemical formula + adduct type)

# %%
NAP_SIRIUS_sumup
# Out:
# [(501,
#   [['MetFragSMILES_1_LTS0013335 , NYEXXEJYGVAGEE_structure_C19H28O2[M + H]+'],
#    ['MetFragSMILES_2_LTS0024768 , PIJPSWNOKIPSCP_structure_C19H28O2[M + H]+']]),
#  (1111,
#   [['MetFragSMILES_1_LTS0064099 , YCLCHPWRGSDZKL_structure_C20H28O[M + H]+'],
#    ['MetFragSMILES_2_LTS0035059 , ISHVJVXYPLFKAL_structure_C20H28O[M + H]+']]),
#  (1006,
#   [['MetFragSMILES_1_LTS0254324 , MXPXAZNVQUWDFH_structure_C20H26O4[M + H]+'],
#    ['MetFragSMILES_3_LTS0046848 , MXCOJKLBLFWFNI_structure_C20H26O4[M + H]+'],
#    ['MetFragSMILES_2_LTS0002654 , PKAIECBWQZFYRP_structure_C20H26O4[M + H]+']]),
#  (565,
#   [['MetFragSMILES_1_LTS0171116 , SGCHZBKQDFNHSL_structure_C19H26O3[M + H]+']]),
#  (619,
#   [['MetFragSMILES_1_LTS0088733 , NGBRPGLXCQJIPU_structure_C20H26O2[M + H]+']]),
#  (1272,
#   [['MetFragSMILES_2_LTS0034017 , NFWKVWVWBFBAOV_structure_C20H28O2[M + H]+'],
#    ['MetFragSMILES_3_LTS0151331 , PRZSMDYEVUSNJM_structure_C20H28O2[M + H]+'],
#    ['MetFragSMILES_1_LTS0057168 , IQHBZJPFGJKKJI_structure_C20H28O2[M + H]+']]),
#  (873,
#   [['MetFragSMILES_1_LTS0092634 , ZSHVSBCOLVBOLB_structure_C24H32O5[M + H]+']]),
#  (828,
#   [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']]),
#  (1068,
#   [['MetFragSMILES_2_LTS0201039 , VOYZLKWKVLYJHD_structure_C30H46O3[M + H]+'],
#    ['MetFragSMILES_1_LTS0049064 , DKGGOTRAZUOHPG_structure_C30H46O3[M + H]+'],
#    ['MetFragSMILES_3_LTS0004634 , GVVASFXQODQNLW_structure_C30H46O3[M + H]+']]),
#  (1080,
#   [['MetFragSMILES_1_LTS0002592 , SIYBXEYFWKPLJC_structure_C28H46O3[M + H]+']]),
#  (896,
#   [['MetFragSMILES_1_LTS0184224 , CYOURYOZWLIJFB_structure_C20H32O[M + H]+'],
#    ['MetFragSMILES_2_LTS0185646 , PMRGRURZTGRVDP_structure_C20H32O[M + H]+'],
#    ['MetFragSMILES_3_LTS0150156 , GQRUHVMVWNKUFW_structure_C20H32O[M + H]+']]),
#  (657,
#   [['MetFragSMILES_1_LTS0108097 , PTQFIYQNKVSVGM_structure_C19H26O2[M + H]+']]),
#  (787,
#   [['MetFragSMILES_3_LTS0046650 , MLBYBBUZURKHAW_structure_C20H30O2[M + H]+'],
#    ['MetFragSMILES_1_LTS0203405 , FKCPLBHSZGVMNG_structure_C20H30O2[M + H]+'],
#    ['MetFragSMILES_2_LTS0243815 , PORHOKHIMOFMMH_structure_C20H30O2[M + H]+']]),
#  (590,
#   [['MetFragSMILES_1_LTS0108097 , PTQFIYQNKVSVGM_structure_C19H26O2[M + H]+']]),
#  (1454,
#   [['MetFragSMILES_1_LTS0270354 , AOSOLLDONLOYAH_structure_C29H48O2[M + Na]+'],
#    ['MetFragSMILES_2_LTS0212919 , HMMVBUVVQLUGQA_structure_C29H48O2[M + Na]+']]),
#  (529,
#   [['MetFragSMILES_1_LTS0194549 , QUAMTGJKVDWJEQ_structure_C21H26O3[M + H]+']]),
#  (552,
#   [['MetFragSMILES_2_LTS0135808 , QMSWKASVXHXIKB_structure_C20H28O5[M + Na]+'],
#    ['MetFragSMILES_1_LTS0083162 , CKMAUJLOUQNVRZ_structure_C20H28O5[M + Na]+'],
#    ['MetFragSMILES_3_LTS0022360 , CFJWRSMUQIAHTA_structure_C20H28O5[M + Na]+']]),
#  (561,
#   [['MetFragSMILES_2_LTS0056945 , CUXCAMYFFUWHQV_structure_C20H28O4[M + H]+'],
#    ['MetFragSMILES_3_LTS0027960 , ALGYTGOYQATWBA_structure_C20H28O4[M + H]+'],
#    ['MetFragSMILES_1_LTS0255603 , HEIKHXMGSYQVGA_structure_C20H28O4[M + H]+']]),
#  (1305,
#   [['MetFragSMILES_3_LTS0079225 , WTFWUWLORKLWCJ_structure_C20H34O2[M + Na]+'],
#    ['MetFragSMILES_2_LTS0165489 , BSKNIQVPQSFUSP_structure_C20H34O2[M + Na]+']]),
#  (999,
#   [['MetFragSMILES_3_LTS0114300 , MDWQSNIQXHNTCK_structure_C20H30O[M + H]+'],
#    ['MetFragSMILES_1_LTS0000316 , WSKGRAGZAQRSED_structure_C20H30O[M + H]+'],
#    ['MetFragSMILES_2_LTS0149356 , JMYBTVXXLMTVKS_structure_C20H30O[M + H]+']]),
#  (586,
#   [['MetFragSMILES_2_LTS0000316 , WSKGRAGZAQRSED_structure_C20H30O[M + H]+'],
#    ['MetFragSMILES_1_LTS0149356 , JMYBTVXXLMTVKS_structure_C20H30O[M + H]+'],
#    ['MetFragSMILES_3_LTS0127038 , CUFRQYVSJJHEKT_structure_C20H30O[M + H]+']]),
#  (1347,
#   [['MetFragSMILES_1_LTS0041481 , KUMASSYJGMPIHK_structure_C31H50O4[M + H]+']]),
#  (336,
#   [['MetFragSMILES_1_LTS0269975 , RNDNBGULZNCSNB_structure_C30H22O10[M + H]+']]),
#  (691,
#   [['MetFragSMILES_2_LTS0184224 , CYOURYOZWLIJFB_structure_C20H32O[M + H]+'],
#    ['MetFragSMILES_3_LTS0185646 , PMRGRURZTGRVDP_structure_C20H32O[M + H]+'],
#    ['MetFragSMILES_1_LTS0150156 , GQRUHVMVWNKUFW_structure_C20H32O[M + H]+']]),
#  (821,
#   [['MetFragSMILES_1_LTS0108097 , PTQFIYQNKVSVGM_structure_C19H26O2[M + Na]+']]),
#  (1476,
#   [['MetFragSMILES_1_LTS0064099 , YCLCHPWRGSDZKL_structure_C20H28O[M + H]+'],
#    ['MetFragSMILES_2_LTS0035059 , ISHVJVXYPLFKAL_structure_C20H28O[M + H]+']]),
#  (674,
#   [['MetFragSMILES_2_LTS0034017 , NFWKVWVWBFBAOV_structure_C20H28O2[M + H]+'],
#    ['MetFragSMILES_3_LTS0151331 , PRZSMDYEVUSNJM_structure_C20H28O2[M + H]+'],
#    ['MetFragSMILES_1_LTS0057168 , IQHBZJPFGJKKJI_structure_C20H28O2[M + H]+']]),
#  (1322,
#   [['MetFragSMILES_3_LTS0220552 , IQVKGPHVUDYNPT_structure_C26H40O6[M + H]+'],
#    ['MetFragSMILES_2_LTS0201681 , NASOHMFLGZORKU_structure_C26H40O6[M + H]+'],
#    ['MetFragSMILES_1_LTS0034815 , AHBQIYSLXQMIEO_structure_C26H40O6[M + H]+']]),
#  (1356,
#   [['MetFragSMILES_1_LTS0087433 , SKHNEXWRHKHJFZ_structure_C29H44O2[M + H]+']]),
#  (230,
#   [['MetFragSMILES_1_LTS0044016 , OTWLSQPCSOEBAY_structure_C20H18O7[M + Na]+']]),
#  (948,
#   [['MetFragSMILES_3_LTS0114300 , MDWQSNIQXHNTCK_structure_C20H30O[M + H]+'],
#    ['MetFragSMILES_1_LTS0000316 , WSKGRAGZAQRSED_structure_C20H30O[M + H]+'],
#    ['MetFragSMILES_2_LTS0149356 , JMYBTVXXLMTVKS_structure_C20H30O[M + H]+']]),
#  (536,
#   [['MetFragSMILES_1_LTS0232556 , VUSNLFYUMKLEAV_structure_C19H24O3[M + H]+'],
#    ['MetFragSMILES_2_LTS0105708 , QDCGSCBAIQIGDY_structure_C19H24O3[M + H]+']]),
#  (1127,
#   [['MetFragSMILES_2_LTS0055409 , CDCKBLNAQWOFID_structure_C30H46O2[M + H]+'],
#    ['MetFragSMILES_3_LTS0106688 , TWBVZVAEDWRAJO_structure_C30H46O2[M + H]+'],
#    ['MetFragSMILES_1_LTS0041018 , VZPCWSKCBLYYSO_structure_C30H46O2[M + H]+']]),
#  (1089,
#   [['MetFragSMILES_1_LTS0160094 , VZCCETWTMQHEPK_structure_C18H30O2[M + H]+'],
#    ['MetFragSMILES_2_LTS0132789 , DTOSIQBPPRVQHS_structure_C18H30O2[M + H]+'],
#    ['MetFragSMILES_3_LTS0214201 , HXQHFNIKBKZGRP_structure_C18H30O2[M + H]+']]),
#  (572,
#   [['MetFragSMILES_1_LTS0255421 , ROGUIJKVZZROIQ_structure_C20H24O5[M + H]+']]),
#  (909,
#   [['MetFragSMILES_1_LTS0013335 , NYEXXEJYGVAGEE_structure_C19H28O2[M + H]+'],
#    ['MetFragSMILES_2_LTS0024768 , PIJPSWNOKIPSCP_structure_C19H28O2[M + H]+']]),
#  (1345,
#   [['MetFragSMILES_3_LTS0002171 , ABPDEYSUVLXYCB_structure_C31H48O4[M + H]+'],
#    ['MetFragSMILES_2_LTS0037468 , BGBKLMBLKNDJMK_structure_C31H48O4[M + H]+'],
#    ['MetFragSMILES_1_LTS0022895 , IIPIWCJQGIFRHH_structure_C31H48O4[M + H]+']]),
#  (1002,
#   [['MetFragSMILES_1_LTS0002592 , SIYBXEYFWKPLJC_structure_C28H46O3[M + H]+']]),
#  (993,
#   [['MetFragSMILES_1_LTS0088733 , NGBRPGLXCQJIPU_structure_C20H26O2[M + H]+']]),
#  (1023,
#   [['MetFragSMILES_2_LTS0240388 , RGXBCSRGWBMBCF_structure_C30H46O4[M + H]+'],
#    ['MetFragSMILES_1_LTS0160555 , UPHZQTDFAGIZQK_structure_C30H46O4[M + H]+'],
#    ['MetFragSMILES_3_LTS0266507 , VGVAABHRCNAZRM_structure_C30H46O4[M + H]+']]),
#  (1969,
#   [['MetFragSMILES_2_LTS0212919 , HMMVBUVVQLUGQA_structure_C29H48O2[M + H]+'],
#    ['MetFragSMILES_1_LTS0270354 , AOSOLLDONLOYAH_structure_C29H48O2[M + H]+']]),
#  (1380,
#   [['MetFragSMILES_1_LTS0013015 , JWBQJSCILWCBJO_structure_C30H44O3[M + H]+']]),
#  (165,
#   [['MetFragSMILES_2_LTS0264219 , BDMACDVLTOBWFC_structure_C30H22O12[M + H]+'],
#    ['MetFragSMILES_1_LTS0157787 , KRGQPZUWMNJLOQ_structure_C30H22O12[M + H]+']]),
#  (748,
#   [['MetFragSMILES_1_LTS0013335 , NYEXXEJYGVAGEE_structure_C19H28O2[M + H]+'],
#    ['MetFragSMILES_2_LTS0024768 , PIJPSWNOKIPSCP_structure_C19H28O2[M + H]+']]),
#  (276,
#   [['MetFragSMILES_1_LTS0269975 , RNDNBGULZNCSNB_structure_C30H22O10[M + H]+']]),
#  (1136,
#   [['MetFragSMILES_1_LTS0013015 , JWBQJSCILWCBJO_structure_C30H44O3[M + H]+']]),
#  (1250,
#   [['MetFragSMILES_1_LTS0054271 , ILQLITDRYFHAGM_structure_C20H28O3[M + H]+'],
#    ['MetFragSMILES_3_LTS0093361 , GPFVBJYXFRIOFB_structure_C20H28O3[M + H]+'],
#    ['MetFragSMILES_2_LTS0087280 , AYDJDNNMKHXZOQ_structure_C20H28O3[M + H]+']]),
#  (1323,
#   [['MetFragSMILES_3_LTS0079225 , WTFWUWLORKLWCJ_structure_C20H34O2[M + Na]+'],
#    ['MetFragSMILES_2_LTS0165489 , BSKNIQVPQSFUSP_structure_C20H34O2[M + Na]+']]),
#  (284,
#   [['MetFragSMILES_2_LTS0214803 , VRXLDKQKMDSSHS_structure_C30H22O11[M + H]+'],
#    ['MetFragSMILES_1_LTS0192920 , OAWGSMCKVUHHTO_structure_C30H22O11[M + H]+']]),
#  (288,
#   [['MetFragSMILES_1_LTS0107505 , IZQSVPBOUDKVDZ_structure_C16H12O7[M + H]+'],
#    ['MetFragSMILES_2_LTS0209810 , JGUZGNYPMHHYRK_structure_C16H12O7[M + H]+']]),
#  (649,
#   [['MetFragSMILES_1_LTS0013335 , NYEXXEJYGVAGEE_structure_C19H28O2[M + H]+'],
#    ['MetFragSMILES_2_LTS0024768 , PIJPSWNOKIPSCP_structure_C19H28O2[M + H]+']]),
#  (1425,
#   [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']]),
#  (1349,
#   [['MetFragSMILES_2_LTS0248187 , QMTZBWPBIQZLBJ_structure_C21H30O3[M + H]+'],
#    ['MetFragSMILES_1_LTS0257851 , QBAITYMIZWFOLG_structure_C21H30O3[M + H]+'],
#    ['MetFragSMILES_3_LTS0067008 , IGUDTNVZIOWVIV_structure_C21H30O3[M + H]+']]),
#  (945,
#   [['MetFragSMILES_2_LTS0132789 , DTOSIQBPPRVQHS_structure_C18H30O2[M + H]+'],
#    ['MetFragSMILES_1_LTS0160094 , VZCCETWTMQHEPK_structure_C18H30O2[M + H]+'],
#    ['MetFragSMILES_3_LTS0214201 , HXQHFNIKBKZGRP_structure_C18H30O2[M + H]+']]),
#  (1821,
#   [['MetFragSMILES_1_LTS0002592 , SIYBXEYFWKPLJC_structure_C28H46O3[M + Na]+']]),
#  (1316,
#   [['MetFragSMILES_1_LTS0155650 , FITFAFMCWGCVDQ_structure_C19H24O[M + H]+']]),
#  (1288,
#   [['MetFragSMILES_1_LTS0054271 , ILQLITDRYFHAGM_structure_C20H28O3[M + H]+'],
#    ['MetFragSMILES_2_LTS0087280 , AYDJDNNMKHXZOQ_structure_C20H28O3[M + H]+'],
#    ['MetFragSMILES_3_LTS0093361 , GPFVBJYXFRIOFB_structure_C20H28O3[M + H]+']]),
#  (1332,
#   [['MetFragSMILES_2_LTS0248187 , QMTZBWPBIQZLBJ_structure_C21H30O3[M + H]+'],
#    ['MetFragSMILES_1_LTS0257851 , QBAITYMIZWFOLG_structure_C21H30O3[M + H]+'],
#    ['MetFragSMILES_3_LTS0067008 , IGUDTNVZIOWVIV_structure_C21H30O3[M + H]+']]),
#  (2139,
#   [['MetFragSMILES_1_LTS0212919 , HMMVBUVVQLUGQA_structure_C29H48O2[M + H]+'],
#    ['MetFragSMILES_2_LTS0270354 , AOSOLLDONLOYAH_structure_C29H48O2[M + H]+']]),
#  (690,
#   [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']]),
#  (604,
#   [['MetFragSMILES_1_LTS0013335 , NYEXXEJYGVAGEE_structure_C19H28O2[M + H]+'],
#    ['MetFragSMILES_2_LTS0024768 , PIJPSWNOKIPSCP_structure_C19H28O2[M + H]+']]),
#  (1003,
#   [['MetFragSMILES_1_LTS0220552 , IQVKGPHVUDYNPT_structure_C26H40O6[M + H]+'],
#    ['MetFragSMILES_2_LTS0201681 , NASOHMFLGZORKU_structure_C26H40O6[M + H]+'],
#    ['MetFragSMILES_3_LTS0034815 , AHBQIYSLXQMIEO_structure_C26H40O6[M + H]+']]),
#  (1357,
#   [['MetFragSMILES_2_LTS0061235 , KMEQUVNVNHTHSM_structure_C23H36O4[M + H]+'],
#    ['MetFragSMILES_3_LTS0069487 , LODVZNAZFNRTCG_structure_C23H36O4[M + H]+'],
#    ['MetFragSMILES_1_LTS0196897 , AORYFYLFZDBOMS_structure_C23H36O4[M + H]+']]),
#  (1013,
#   [['MetFragSMILES_1_LTS0049703 , YBQWVVDWBNHYPN_structure_C31H48O6[M + Na]+']]),
#  (754,
#   [['MetFragSMILES_1_LTS0088733 , NGBRPGLXCQJIPU_structure_C20H26O2[M + Na]+']]),
#  (542,
#   [['MetFragSMILES_1_LTS0064099 , YCLCHPWRGSDZKL_structure_C20H28O[M + H]+'],
#    ['MetFragSMILES_2_LTS0035059 , ISHVJVXYPLFKAL_structure_C20H28O[M + H]+']]),
#  (1426,
#   [['MetFragSMILES_1_LTS0019867 , JEOZUAHPKAVXSF_structure_C20H32O[M + H]+'],
#    ['MetFragSMILES_3_LTS0102281 , DUEINKIQNGZKPL_structure_C20H32O[M + H]+'],
#    ['MetFragSMILES_2_LTS0109755 , ATQOOBSXQVRQPY_structure_C20H32O[M + H]+']]),
#  (1470,
#   [['MetFragSMILES_2_LTS0061235 , KMEQUVNVNHTHSM_structure_C23H36O4[M + Na]+'],
#    ['MetFragSMILES_1_LTS0196897 , AORYFYLFZDBOMS_structure_C23H36O4[M + Na]+'],
#    ['MetFragSMILES_3_LTS0069487 , LODVZNAZFNRTCG_structure_C23H36O4[M + Na]+']]),
#  (688,
#   [['MetFragSMILES_1_LTS0048384 , JXHQWTYFUSHCGX_structure_C19H28O4[M + H]+'],
#    ['MetFragSMILES_2_LTS0266553 , FZMONKRUPXQHKO_structure_C19H28O4[M + H]+']]),
#  (1249,
#   [['MetFragSMILES_1_LTS0080951 , PGZCJOPTDHWYES_structure_C21H30O2[M + H]+']]),
#  (1267,
#   [['MetFragSMILES_1_LTS0224467 , NFRXSIOHGADFRG_structure_C30H48O[M + H]+']]),
#  (129,
#   [['MetFragSMILES_1_LTS0094372 , CDRPUGZCRXZLFL_structure_C14H12O4[M + H]+']]),
#  (555,
#   [['MetFragSMILES_3_LTS0046650 , MLBYBBUZURKHAW_structure_C20H30O2[M + H]+'],
#    ['MetFragSMILES_1_LTS0203405 , FKCPLBHSZGVMNG_structure_C20H30O2[M + H]+'],
#    ['MetFragSMILES_2_LTS0243815 , PORHOKHIMOFMMH_structure_C20H30O2[M + H]+']]),
#  (543,
#   [['MetFragSMILES_2_LTS0046848 , MXCOJKLBLFWFNI_structure_C20H26O4[M + H]+'],
#    ['MetFragSMILES_1_LTS0254324 , MXPXAZNVQUWDFH_structure_C20H26O4[M + H]+'],
#    ['MetFragSMILES_3_LTS0002654 , PKAIECBWQZFYRP_structure_C20H26O4[M + H]+']]),
#  (1185,
#   [['MetFragSMILES_1_LTS0180660 , AXKQOCLPWRXCRI_structure_C20H26O3[M + H]+'],
#    ['MetFragSMILES_2_LTS0229171 , MSWJSDLNPCSSNW_structure_C20H26O3[M + H]+'],
#    ['MetFragSMILES_3_LTS0074326 , ISECDNAMJMNAHZ_structure_C20H26O3[M + H]+']]),
#  (944,
#   [['MetFragSMILES_1_LTS0064099 , YCLCHPWRGSDZKL_structure_C20H28O[M + H]+'],
#    ['MetFragSMILES_2_LTS0035059 , ISHVJVXYPLFKAL_structure_C20H28O[M + H]+']]),
#  (423,
#   [['MetFragSMILES_1_LTS0171116 , SGCHZBKQDFNHSL_structure_C19H26O3[M + H]+']]),
#  (1474,
#   [['MetFragSMILES_1_LTS0160094 , VZCCETWTMQHEPK_structure_C18H30O2[M + H]+'],
#    ['MetFragSMILES_2_LTS0214201 , HXQHFNIKBKZGRP_structure_C18H30O2[M + H]+'],
#    ['MetFragSMILES_3_LTS0132789 , DTOSIQBPPRVQHS_structure_C18H30O2[M + H]+']]),
#  (1307,
#   [['MetFragSMILES_2_LTS0201039 , VOYZLKWKVLYJHD_structure_C30H46O3[M + H]+'],
#    ['MetFragSMILES_1_LTS0049064 , DKGGOTRAZUOHPG_structure_C30H46O3[M + H]+'],
#    ['MetFragSMILES_3_LTS0004634 , GVVASFXQODQNLW_structure_C30H46O3[M + H]+']]),
#  (541,
#   [['MetFragSMILES_1_LTS0083733 , DWHTYLMRWXUGJL_structure_C17H22O3[M + Na]+']]),
#  (956,
#   [['MetFragSMILES_3_LTS0046650 , MLBYBBUZURKHAW_structure_C20H30O2[M + Na]+'],
#    ['MetFragSMILES_1_LTS0203405 , FKCPLBHSZGVMNG_structure_C20H30O2[M + Na]+'],
#    ['MetFragSMILES_2_LTS0243815 , PORHOKHIMOFMMH_structure_C20H30O2[M + Na]+']]),
#  (1867,
#   [['MetFragSMILES_2_LTS0240596 , QEMIUYHLZNNZQN_structure_C32H50O4[M + H]+'],
#    ['MetFragSMILES_1_LTS0220282 , NWUYJACIJALREE_structure_C32H50O4[M + H]+']]),
#  (998,
#   [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']]),
#  (1219,
#   [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']]),
#  (717,
#   [['MetFragSMILES_3_LTS0114300 , MDWQSNIQXHNTCK_structure_C20H30O[M + H]+'],
#    ['MetFragSMILES_2_LTS0000316 , WSKGRAGZAQRSED_structure_C20H30O[M + H]+'],
#    ['MetFragSMILES_1_LTS0149356 , JMYBTVXXLMTVKS_structure_C20H30O[M + H]+']]),
#  (612,
#   [['MetFragSMILES_1_LTS0266553 , FZMONKRUPXQHKO_structure_C19H28O4[M + H]+'],
#    ['MetFragSMILES_2_LTS0048384 , JXHQWTYFUSHCGX_structure_C19H28O4[M + H]+']]),
#  (1447,
#   [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']]),
#  (2479,
#   [['MetFragSMILES_3_LTS0029311 , HCXVJBMSMIARIN_structure_C29H48O[M + H]+'],
#    ['MetFragSMILES_2_LTS0214714 , KYOFIJXMVNQYFC_structure_C29H48O[M + H]+'],
#    ['MetFragSMILES_1_LTS0003409 , RUVUHIUYGJBLGI_structure_C29H48O[M + H]+']]),
#  (1189,
#   [['MetFragSMILES_1_LTS0064099 , YCLCHPWRGSDZKL_structure_C20H28O[M + H]+'],
#    ['MetFragSMILES_2_LTS0035059 , ISHVJVXYPLFKAL_structure_C20H28O[M + H]+']]),
#  (904,
#   [['MetFragSMILES_1_LTS0210076 , QUUCYKKMFLJLFS_structure_C20H30[M + H]+']]),
#  (1606,
#   [['MetFragSMILES_3_LTS0258577 , VYWGLUCGRVXWKB_structure_C20H32[M + H]+'],
#    ['MetFragSMILES_2_LTS0107403 , DMHADBQKVWXPPM_structure_C20H32[M + H]+'],
#    ['MetFragSMILES_1_LTS0048295 , BBPXZLJCPUPNGH_structure_C20H32[M + H]+']]),
#  (849,
#   [['MetFragSMILES_3_LTS0034017 , NFWKVWVWBFBAOV_structure_C20H28O2[M + H]+'],
#    ['MetFragSMILES_2_LTS0151331 , PRZSMDYEVUSNJM_structure_C20H28O2[M + H]+'],
#    ['MetFragSMILES_1_LTS0057168 , IQHBZJPFGJKKJI_structure_C20H28O2[M + H]+']]),
#  (760,
#   [['MetFragSMILES_2_LTS0064099 , YCLCHPWRGSDZKL_structure_C20H28O[M + H]+'],
#    ['MetFragSMILES_1_LTS0035059 , ISHVJVXYPLFKAL_structure_C20H28O[M + H]+']]),
#  (931,
#   [['MetFragSMILES_1_LTS0241153 , YZXBAPSDXZZRGB_structure_C20H32O2[M + H]+'],
#    ['MetFragSMILES_3_LTS0068275 , JFQBNOIJWROZGE_structure_C20H32O2[M + H]+'],
#    ['MetFragSMILES_2_LTS0158625 , OJSKJQFODPKTBT_structure_C20H32O2[M + H]+']]),
#  (158,
#   [['MetFragSMILES_1_LTS0094372 , CDRPUGZCRXZLFL_structure_C14H12O4[M + H]+']]),
#  (949,
#   [['MetFragSMILES_1_LTS0118921 , SOJWLJKPIIODOH_structure_C19H28O[M + H]+']]),
#  (1914,
#   [['MetFragSMILES_2_LTS0212919 , HMMVBUVVQLUGQA_structure_C29H48O2[M + H]+'],
#    ['MetFragSMILES_1_LTS0270354 , AOSOLLDONLOYAH_structure_C29H48O2[M + H]+']]),
#  (1092,
#   [['MetFragSMILES_2_LTS0248187 , QMTZBWPBIQZLBJ_structure_C21H30O3[M + H]+'],
#    ['MetFragSMILES_1_LTS0067008 , IGUDTNVZIOWVIV_structure_C21H30O3[M + H]+'],
#    ['MetFragSMILES_3_LTS0257851 , QBAITYMIZWFOLG_structure_C21H30O3[M + H]+']]),
#  (1449,
#   [['MetFragSMILES_1_LTS0019867 , JEOZUAHPKAVXSF_structure_C20H32O[M + H]+'],
#    ['MetFragSMILES_3_LTS0102281 , DUEINKIQNGZKPL_structure_C20H32O[M + H]+'],
#    ['MetFragSMILES_2_LTS0109755 , ATQOOBSXQVRQPY_structure_C20H32O[M + H]+']]),
#  (665,
#   [['MetFragSMILES_1_LTS0155650 , FITFAFMCWGCVDQ_structure_C19H24O[M + H]+']]),
#  (1030,
#   [['MetFragSMILES_1_LTS0013335 , NYEXXEJYGVAGEE_structure_C19H28O2[M + Na]+'],
#    ['MetFragSMILES_2_LTS0024768 , PIJPSWNOKIPSCP_structure_C19H28O2[M + Na]+']]),
#  (1026,
#   [['MetFragSMILES_1_LTS0088733 , NGBRPGLXCQJIPU_structure_C20H26O2[M + H]+']]),
#  (279,
#   [['MetFragSMILES_1_LTS0107505 , IZQSVPBOUDKVDZ_structure_C16H12O7[M + H]+'],
#    ['MetFragSMILES_2_LTS0209810 , JGUZGNYPMHHYRK_structure_C16H12O7[M + H]+']]),
#  (961,
#   [['MetFragSMILES_1_LTS0155650 , FITFAFMCWGCVDQ_structure_C19H24O[M + H]+']]),
#  (616,
#   [['MetFragSMILES_1_LTS0171116 , SGCHZBKQDFNHSL_structure_C19H26O3[M + Na]+']]),
#  (888,
#   [['MetFragSMILES_1_LTS0079469 , UKOKENMLXFNPEJ_structure_C20H22O3[M + H]+']]),
#  (318,
#   [['MetFragSMILES_2_LTS0214803 , VRXLDKQKMDSSHS_structure_C30H22O11[M + H]+'],
#    ['MetFragSMILES_1_LTS0192920 , OAWGSMCKVUHHTO_structure_C30H22O11[M + H]+']]),
#  (716,
#   [['MetFragSMILES_2_LTS0013015 , JWBQJSCILWCBJO_structure_C30H44O3[M + H]+']]),
#  (147,
#   [['MetFragSMILES_1_LTS0203074 , RSYUFYQTACJFML_structure_C15H14O5[M + H]+']])]

# %%
 for x in NAP_SIRIUS_sumup:
        print(x[0])
        list_MF_NAP_SIRIUS=[]
        list_SIRIUS_NAP_SIRIUS=[]
        for i in range(len(x[1])):
            list_MF_NAP_SIRIUS.append(str(x[1][i][0].split(' , ')[0].split('_')[2] + ' MF' + str(x[1][i][0].split(' , ')[0].split('_')[1])))      
            list_SIRIUS_NAP_SIRIUS.append(str(x[1][i][0].split(' , ')[1].split('_')[0] + ' ' +str(x[1][i][0].split(' , ')[1].split('_')[2])))
            print(list_MF_NAP_SIRIUS)
# Out:
# 501
# ['LTS0013335 MF1']
# ['LTS0013335 MF1', 'LTS0024768 MF2']
# 1111
# ['LTS0064099 MF1']
# ['LTS0064099 MF1', 'LTS0035059 MF2']
# 1006
# ['LTS0254324 MF1']
# ['LTS0254324 MF1', 'LTS0046848 MF3']
# ['LTS0254324 MF1', 'LTS0046848 MF3', 'LTS0002654 MF2']
# 565
# ['LTS0171116 MF1']
# 619
# ['LTS0088733 MF1']
# 1272
# ['LTS0034017 MF2']
# ['LTS0034017 MF2', 'LTS0151331 MF3']
# ['LTS0034017 MF2', 'LTS0151331 MF3', 'LTS0057168 MF1']
# 873
# ['LTS0092634 MF1']
# 828
# ['LTS0210076 MF1']
# 1068
# ['LTS0201039 MF2']
# ['LTS0201039 MF2', 'LTS0049064 MF1']
# ['LTS0201039 MF2', 'LTS0049064 MF1', 'LTS0004634 MF3']
# 1080
# ['LTS0002592 MF1']
# 896
# ['LTS0184224 MF1']
# ['LTS0184224 MF1', 'LTS0185646 MF2']
# ['LTS0184224 MF1', 'LTS0185646 MF2', 'LTS0150156 MF3']
# 657
# ['LTS0108097 MF1']
# 787
# ['LTS0046650 MF3']
# ['LTS0046650 MF3', 'LTS0203405 MF1']
# ['LTS0046650 MF3', 'LTS0203405 MF1', 'LTS0243815 MF2']
# 590
# ['LTS0108097 MF1']
# 1454
# ['LTS0270354 MF1']
# ['LTS0270354 MF1', 'LTS0212919 MF2']
# 529
# ['LTS0194549 MF1']
# 552
# ['LTS0135808 MF2']
# ['LTS0135808 MF2', 'LTS0083162 MF1']
# ['LTS0135808 MF2', 'LTS0083162 MF1', 'LTS0022360 MF3']
# 561
# ['LTS0056945 MF2']
# ['LTS0056945 MF2', 'LTS0027960 MF3']
# ['LTS0056945 MF2', 'LTS0027960 MF3', 'LTS0255603 MF1']
# 1305
# ['LTS0079225 MF3']
# ['LTS0079225 MF3', 'LTS0165489 MF2']
# 999
# ['LTS0114300 MF3']
# ['LTS0114300 MF3', 'LTS0000316 MF1']
# ['LTS0114300 MF3', 'LTS0000316 MF1', 'LTS0149356 MF2']
# 586
# ['LTS0000316 MF2']
# ['LTS0000316 MF2', 'LTS0149356 MF1']
# ['LTS0000316 MF2', 'LTS0149356 MF1', 'LTS0127038 MF3']
# 1347
# ['LTS0041481 MF1']
# 336
# ['LTS0269975 MF1']
# 691
# ['LTS0184224 MF2']
# ['LTS0184224 MF2', 'LTS0185646 MF3']
# ['LTS0184224 MF2', 'LTS0185646 MF3', 'LTS0150156 MF1']
# 821
# ['LTS0108097 MF1']
# 1476
# ['LTS0064099 MF1']
# ['LTS0064099 MF1', 'LTS0035059 MF2']
# 674
# ['LTS0034017 MF2']
# ['LTS0034017 MF2', 'LTS0151331 MF3']
# ['LTS0034017 MF2', 'LTS0151331 MF3', 'LTS0057168 MF1']
# 1322
# ['LTS0220552 MF3']
# ['LTS0220552 MF3', 'LTS0201681 MF2']
# ['LTS0220552 MF3', 'LTS0201681 MF2', 'LTS0034815 MF1']
# 1356
# ['LTS0087433 MF1']
# 230
# ['LTS0044016 MF1']
# 948
# ['LTS0114300 MF3']
# ['LTS0114300 MF3', 'LTS0000316 MF1']
# ['LTS0114300 MF3', 'LTS0000316 MF1', 'LTS0149356 MF2']
# 536
# ['LTS0232556 MF1']
# ['LTS0232556 MF1', 'LTS0105708 MF2']
# 1127
# ['LTS0055409 MF2']
# ['LTS0055409 MF2', 'LTS0106688 MF3']
# ['LTS0055409 MF2', 'LTS0106688 MF3', 'LTS0041018 MF1']
# 1089
# ['LTS0160094 MF1']
# ['LTS0160094 MF1', 'LTS0132789 MF2']
# ['LTS0160094 MF1', 'LTS0132789 MF2', 'LTS0214201 MF3']
# 572
# ['LTS0255421 MF1']
# 909
# ['LTS0013335 MF1']
# ['LTS0013335 MF1', 'LTS0024768 MF2']
# 1345
# ['LTS0002171 MF3']
# ['LTS0002171 MF3', 'LTS0037468 MF2']
# ['LTS0002171 MF3', 'LTS0037468 MF2', 'LTS0022895 MF1']
# 1002
# ['LTS0002592 MF1']
# 993
# ['LTS0088733 MF1']
# 1023
# ['LTS0240388 MF2']
# ['LTS0240388 MF2', 'LTS0160555 MF1']
# ['LTS0240388 MF2', 'LTS0160555 MF1', 'LTS0266507 MF3']
# 1969
# ['LTS0212919 MF2']
# ['LTS0212919 MF2', 'LTS0270354 MF1']
# 1380
# ['LTS0013015 MF1']
# 165
# ['LTS0264219 MF2']
# ['LTS0264219 MF2', 'LTS0157787 MF1']
# 748
# ['LTS0013335 MF1']
# ['LTS0013335 MF1', 'LTS0024768 MF2']
# 276
# ['LTS0269975 MF1']
# 1136
# ['LTS0013015 MF1']
# 1250
# ['LTS0054271 MF1']
# ['LTS0054271 MF1', 'LTS0093361 MF3']
# ['LTS0054271 MF1', 'LTS0093361 MF3', 'LTS0087280 MF2']
# 1323
# ['LTS0079225 MF3']
# ['LTS0079225 MF3', 'LTS0165489 MF2']
# 284
# ['LTS0214803 MF2']
# ['LTS0214803 MF2', 'LTS0192920 MF1']
# 288
# ['LTS0107505 MF1']
# ['LTS0107505 MF1', 'LTS0209810 MF2']
# 649
# ['LTS0013335 MF1']
# ['LTS0013335 MF1', 'LTS0024768 MF2']
# 1425
# ['LTS0210076 MF1']
# 1349
# ['LTS0248187 MF2']
# ['LTS0248187 MF2', 'LTS0257851 MF1']
# ['LTS0248187 MF2', 'LTS0257851 MF1', 'LTS0067008 MF3']
# 945
# ['LTS0132789 MF2']
# ['LTS0132789 MF2', 'LTS0160094 MF1']
# ['LTS0132789 MF2', 'LTS0160094 MF1', 'LTS0214201 MF3']
# 1821
# ['LTS0002592 MF1']
# 1316
# ['LTS0155650 MF1']
# 1288
# ['LTS0054271 MF1']
# ['LTS0054271 MF1', 'LTS0087280 MF2']
# ['LTS0054271 MF1', 'LTS0087280 MF2', 'LTS0093361 MF3']
# 1332
# ['LTS0248187 MF2']
# ['LTS0248187 MF2', 'LTS0257851 MF1']
# ['LTS0248187 MF2', 'LTS0257851 MF1', 'LTS0067008 MF3']
# 2139
# ['LTS0212919 MF1']
# ['LTS0212919 MF1', 'LTS0270354 MF2']
# 690
# ['LTS0210076 MF1']
# 604
# ['LTS0013335 MF1']
# ['LTS0013335 MF1', 'LTS0024768 MF2']
# 1003
# ['LTS0220552 MF1']
# ['LTS0220552 MF1', 'LTS0201681 MF2']
# ['LTS0220552 MF1', 'LTS0201681 MF2', 'LTS0034815 MF3']
# 1357
# ['LTS0061235 MF2']
# ['LTS0061235 MF2', 'LTS0069487 MF3']
# ['LTS0061235 MF2', 'LTS0069487 MF3', 'LTS0196897 MF1']
# 1013
# ['LTS0049703 MF1']
# 754
# ['LTS0088733 MF1']
# 542
# ['LTS0064099 MF1']
# ['LTS0064099 MF1', 'LTS0035059 MF2']
# 1426
# ['LTS0019867 MF1']
# ['LTS0019867 MF1', 'LTS0102281 MF3']
# ['LTS0019867 MF1', 'LTS0102281 MF3', 'LTS0109755 MF2']
# 1470
# ['LTS0061235 MF2']
# ['LTS0061235 MF2', 'LTS0196897 MF1']
# ['LTS0061235 MF2', 'LTS0196897 MF1', 'LTS0069487 MF3']
# 688
# ['LTS0048384 MF1']
# ['LTS0048384 MF1', 'LTS0266553 MF2']
# 1249
# ['LTS0080951 MF1']
# 1267
# ['LTS0224467 MF1']
# 129
# ['LTS0094372 MF1']
# 555
# ['LTS0046650 MF3']
# ['LTS0046650 MF3', 'LTS0203405 MF1']
# ['LTS0046650 MF3', 'LTS0203405 MF1', 'LTS0243815 MF2']
# 543
# ['LTS0046848 MF2']
# ['LTS0046848 MF2', 'LTS0254324 MF1']
# ['LTS0046848 MF2', 'LTS0254324 MF1', 'LTS0002654 MF3']
# 1185
# ['LTS0180660 MF1']
# ['LTS0180660 MF1', 'LTS0229171 MF2']
# ['LTS0180660 MF1', 'LTS0229171 MF2', 'LTS0074326 MF3']
# 944
# ['LTS0064099 MF1']
# ['LTS0064099 MF1', 'LTS0035059 MF2']
# 423
# ['LTS0171116 MF1']
# 1474
# ['LTS0160094 MF1']
# ['LTS0160094 MF1', 'LTS0214201 MF2']
# ['LTS0160094 MF1', 'LTS0214201 MF2', 'LTS0132789 MF3']
# 1307
# ['LTS0201039 MF2']
# ['LTS0201039 MF2', 'LTS0049064 MF1']
# ['LTS0201039 MF2', 'LTS0049064 MF1', 'LTS0004634 MF3']
# 541
# ['LTS0083733 MF1']
# 956
# ['LTS0046650 MF3']
# ['LTS0046650 MF3', 'LTS0203405 MF1']
# ['LTS0046650 MF3', 'LTS0203405 MF1', 'LTS0243815 MF2']
# 1867
# ['LTS0240596 MF2']
# ['LTS0240596 MF2', 'LTS0220282 MF1']
# 998
# ['LTS0210076 MF1']
# 1219
# ['LTS0210076 MF1']
# 717
# ['LTS0114300 MF3']
# ['LTS0114300 MF3', 'LTS0000316 MF2']
# ['LTS0114300 MF3', 'LTS0000316 MF2', 'LTS0149356 MF1']
# 612
# ['LTS0266553 MF1']
# ['LTS0266553 MF1', 'LTS0048384 MF2']
# 1447
# ['LTS0210076 MF1']
# 2479
# ['LTS0029311 MF3']
# ['LTS0029311 MF3', 'LTS0214714 MF2']
# ['LTS0029311 MF3', 'LTS0214714 MF2', 'LTS0003409 MF1']
# 1189
# ['LTS0064099 MF1']
# ['LTS0064099 MF1', 'LTS0035059 MF2']
# 904
# ['LTS0210076 MF1']
# 1606
# ['LTS0258577 MF3']
# ['LTS0258577 MF3', 'LTS0107403 MF2']
# ['LTS0258577 MF3', 'LTS0107403 MF2', 'LTS0048295 MF1']
# 849
# ['LTS0034017 MF3']
# ['LTS0034017 MF3', 'LTS0151331 MF2']
# ['LTS0034017 MF3', 'LTS0151331 MF2', 'LTS0057168 MF1']
# 760
# ['LTS0064099 MF2']
# ['LTS0064099 MF2', 'LTS0035059 MF1']
# 931
# ['LTS0241153 MF1']
# ['LTS0241153 MF1', 'LTS0068275 MF3']
# ['LTS0241153 MF1', 'LTS0068275 MF3', 'LTS0158625 MF2']
# 158
# ['LTS0094372 MF1']
# 949
# ['LTS0118921 MF1']
# 1914
# ['LTS0212919 MF2']
# ['LTS0212919 MF2', 'LTS0270354 MF1']
# 1092
# ['LTS0248187 MF2']
# ['LTS0248187 MF2', 'LTS0067008 MF1']
# ['LTS0248187 MF2', 'LTS0067008 MF1', 'LTS0257851 MF3']
# 1449
# ['LTS0019867 MF1']
# ['LTS0019867 MF1', 'LTS0102281 MF3']
# ['LTS0019867 MF1', 'LTS0102281 MF3', 'LTS0109755 MF2']
# 665
# ['LTS0155650 MF1']
# 1030
# ['LTS0013335 MF1']
# ['LTS0013335 MF1', 'LTS0024768 MF2']
# 1026
# ['LTS0088733 MF1']
# 279
# ['LTS0107505 MF1']
# ['LTS0107505 MF1', 'LTS0209810 MF2']
# 961
# ['LTS0155650 MF1']
# 616
# ['LTS0171116 MF1']
# 888
# ['LTS0079469 MF1']
# 318
# ['LTS0214803 MF2']
# ['LTS0214803 MF2', 'LTS0192920 MF1']
# 716
# ['LTS0013015 MF2']
# 147
# ['LTS0203074 MF1']

# %% [markdown]
# ##### Write results to the resume file

# %%
for x in range(len(NAP_SIRIUS_sumup)):
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(NAP_SIRIUS_sumup[x][0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=None
    

    list_MF_NAP_SIRIUS=[]
    list_SIRIUS_NAP_SIRIUS=[]
    for i in range(len(NAP_SIRIUS_sumup[x][1])):
        list_MF_NAP_SIRIUS.append(str(NAP_SIRIUS_sumup[x][1][i][0].split(' , ')[0].split('_')[2] + ' MF' + str(NAP_SIRIUS_sumup[x][1][i][0].split(' , ')[0].split('_')[1])))      
        list_SIRIUS_NAP_SIRIUS.append(str(NAP_SIRIUS_sumup[x][1][i][0].split(' , ')[1].split('_')[0] + ' ' +str(NAP_SIRIUS_sumup[x][1][i][0].split(' , ')[1].split('_')[2])))
        Dict_sumup['NAP_SU'][numerous]= list_MF_NAP_SIRIUS
        Dict_sumup['SIRIUS_SU'][numerous]= list_SIRIUS_NAP_SIRIUS 
        
        
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
   
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]='GNPS'
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]=None
    Dict_sumup['3rd_Tool_SU'][numerous]=None
    Dict_sumup['Molecular_Name_SU'][numerous]=None
    Dict_sumup['Confidence_Level'][numerous]='11'

# %% [markdown]
# ##### Apply confidence score = 11 to all nodes that only have NAP_SIRIUS common annotation, without any GNPS candidate

# %%
for x in NAP_SIRIUS_sumup:
    df['All_Tools_confidence'][df['shared name'].tolist().index(x[0])] = 11
# Out:
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\253588388.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['All_Tools_confidence'][df['shared name'].tolist().index(x[0])] = 11 ###au leiur de 4 230814

# %% [markdown]
# #### 2.2 Compare the features that only have NAP_SIRIUS common annotations, without any GNPS candidate,  to 13C NMR annotations

# %%
def compare_to_nmr_annotation3b(df_smiles, common_sumup):
    list_ID=[]
    if len(common_sumup) == 0:
        print('There is no features for the comparison.')
    else:
        df_common_sumup =pd.DataFrame(common_sumup)

        df_common_sumup['inchikey']=None
        df_common_sumup['formula']=None
        df_common_sumup['MF']=None

        for x in range(len(df_common_sumup[0])):
            list_key = []
            list_formula=[]
            list_MF=[]
            for i in range(len(df_common_sumup[1][x])):
                list_key.append(df_common_sumup[1][x][i][0].split(' , ')[1].split('_')[0])
                list_formula.append(df_common_sumup[1][x][i][0].split(' , ')[1].split('_')[2])
                list_MF.append(str(df_common_sumup[1][x][i][0].split(' , ')[0].split('_')[2] + ' MF' + str(df_common_sumup[1][x][i][0].split(' , ')[0].split('_')[1])) )

            df_common_sumup['inchikey'][x] = list_key
            df_common_sumup['formula'][x] = list_formula
            df_common_sumup['MF'][x] = list_MF

            for y in df_smiles['InchiKey'].tolist():
                if y in df_common_sumup['inchikey'][x]:
                    txt = df_common_sumup[0][x], df_common_sumup['MF'][x][df_common_sumup['inchikey'][x].index(y)], y,  df_common_sumup['formula'][x][df_common_sumup['inchikey'][x].index(y)], df_smiles[0][df_smiles['InchiKey'].tolist().index(y)]
#                     print(txt)

                    list_ID.append((txt))
        if len(list_ID) == 0 :
            print('There is no NAP_SIRIUS common annotations feature, without any GNPS candidate, that was confirmed by the 13C NMR workflow.' + '\n')
        else:
            print(f'There are {len(list_ID)} features without any GNPS candidate, but with common NAP_SIRIUS annotations, that were confirmed by the 13C NMR workflow.' + '\n')
            for x in list_ID:
                print(x)
    return list_ID

# %%
xc2=[]
xc2 = compare_to_nmr_annotation3b(df_smiles, NAP_SIRIUS_sumup)
# Out:
# There are 6 features without any GNPS candidate, but with common NAP_SIRIUS annotations, that were confirmed by the 13C NMR workflow.
#
# (1272, 'LTS0034017 MF2', 'NFWKVWVWBFBAOV', 'C20H28O2[M + H]+', 'dehydroabietic-acid')
# (336, 'LTS0269975 MF1', 'RNDNBGULZNCSNB', 'C30H22O10[M + H]+', 'larixinol')
# (674, 'LTS0034017 MF2', 'NFWKVWVWBFBAOV', 'C20H28O2[M + H]+', 'dehydroabietic-acid')
# (276, 'LTS0269975 MF1', 'RNDNBGULZNCSNB', 'C30H22O10[M + H]+', 'larixinol')
# (1185, 'LTS0229171 MF2', 'MSWJSDLNPCSSNW', 'C20H26O3[M + H]+', '7-oxodehydroabietic-acid')
# (849, 'LTS0034017 MF3', 'NFWKVWVWBFBAOV', 'C20H28O2[M + H]+', 'dehydroabietic-acid')
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\826049134.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_common_sumup['inchikey'][x] = list_key
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\826049134.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_common_sumup['formula'][x] = list_formula
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\826049134.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_common_sumup['MF'][x] = list_MF

# %% [markdown]
# ## 3. Now, you would like to compare the remaing features that do not have a common candidate through at least 2 different Mass workflows, to the 13C NMR workflow.

# %% [markdown]
# ##### To select the corresponding features for the comparison, you must select those with a confidence score = 0

# %%
df_final = df.loc[df['All_Tools_confidence'] == 0]

# %% [markdown]
# #### 3.1 Prepare the data for the comparison

# %%
df_final['Smiles_inchikey']=''

df_final['MetFragSMILES1_inchikey']=''
df_final['MetFragSMILES2_inchikey']=''
df_final['MetFragSMILES3_inchikey']=''

df_final['SIRIUS_inchikey']=''
df_final['SIRIUS_formula']=''
# Out:
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1454705014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Smiles_inchikey']=''
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1454705014.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['MetFragSMILES1_inchikey']=''
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1454705014.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['MetFragSMILES2_inchikey']=''
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1454705014.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['MetFragSMILES3_inchikey']=''
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1454705014.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey']=''
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\1454705014.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula']=''

# %%
df_final[['MetFragID1', 'MetFragID2', 'MetFragID3']] = df['MetFragID'].str.split(',', expand=True)
df_final[['MetFragSMILES1', 'MetFragSMILES2', 'MetFragSMILES3']] = df['MetFragSMILES'].str.split(',', expand=True)
# Out:
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2118392208.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[['MetFragID1', 'MetFragID2', 'MetFragID3']] = df['MetFragID'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2118392208.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[['MetFragID1', 'MetFragID2', 'MetFragID3']] = df['MetFragID'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2118392208.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[['MetFragID1', 'MetFragID2', 'MetFragID3']] = df['MetFragID'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2118392208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[['MetFragSMILES1', 'MetFragSMILES2', 'MetFragSMILES3']] = df['MetFragSMILES'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2118392208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[['MetFragSMILES1', 'MetFragSMILES2', 'MetFragSMILES3']] = df['MetFragSMILES'].str.split(',', expand=True)
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2118392208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[['MetFragSMILES1', 'MetFragSMILES2', 'MetFragSMILES3']] = df['MetFragSMILES'].str.split(',', expand=True)

# %% [markdown]
# #### 3.2 Get the corresponding InChIkey for the candidates coming from the corresponding annotation workflow (GNPS, NAP)

# %%
def draw_inchikey(df_final, cat):

    list_smiles=[]
    for x in range(len(df_final[cat].tolist())):
        if str(df_final[cat].tolist()[x]) != 'nan' and str(df_final[cat].tolist()[x]) != 'None':
            list_smiles.append(df_final['shared name'].tolist()[x])
    
    list_smiles= [x for x in list_smiles if math.isnan(x) == False]

    for x in list_smiles:

        ik=''

        m=Chem.MolFromSmiles(df_final[cat].loc[df_final['shared name'] == x].tolist()[0])
        i=Chem.MolToInchi(m)
        ik=Chem.rdinchi.InchiToInchiKey(i).split('-')[0]
        print(f'Feature n° {int(x)} : {ik}')
        df_final[str(cat + '_inchikey')].loc[df_final['shared name'] == x] = ik

# %% [markdown]
# #### 3.2.1 Get the InChIKey for GNPS workflow from the reaming features

# %%
draw_inchikey(df_final, 'Smiles')
# Out:
# [16:42:23] WARNING: Omitted undefined stereo
#
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3163176862.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[str(cat + '_inchikey')].loc[df_final['shared name'] == x] = ik
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
# Feature n° 483 : UVKYPKNCQJIGKV
# Feature n° 1243 : BMVRDJXDSMPZGO
# Feature n° 629 : DAWSYIQAGQMLFS
# Feature n° 1099 : JRNSSSJKIGAFCT
# Feature n° 1117 : WKKBRRFSRMDTJB
# Feature n° 326 : FQWLMRXWKZGLFI
# Feature n° 1278 : VIKNJXKGJWUCNN
# Feature n° 521 : VFLDPWHFBUODDF
# Feature n° 1075 : HFGSQOYIOKBQOW
# Feature n° 111 : KGGUASRIGLRPAX
# Feature n° 1358 : MDZKJHQSJHYOHJ
# Feature n° 1042 : ZQHJXKYYELWEOK
# Feature n° 1401 : YSEVFKWFUGTGAQ
# Feature n° 1195 : MUMGGOZAMZWBJJ
# Feature n° 1012 : KLMZPLYXGZZBCX
# Feature n° 805 : ZQHJXKYYELWEOK
# Feature n° 685 : MUMGGOZAMZWBJJ
# Feature n° 823 : JRNSSSJKIGAFCT
# Feature n° 722 : RBQNDQOKFICJGL
# Feature n° 391 : VIKNJXKGJWUCNN
# Feature n° 882 : OKJCFMUGMSVJBG
# Feature n° 1405 : OKJCFMUGMSVJBG
# Feature n° 301 : BPGBDEHBHGXYDZ
# Feature n° 414 : VIKNJXKGJWUCNN
# Feature n° 642 : UVKZSORBKUEBAZ
# Feature n° 557 : BLGXFZZNTVWLAY
# Feature n° 908 : OKJCFMUGMSVJBG
# Feature n° 537 : RBOXVHNMENFORY
# Feature n° 440 : OKJCFMUGMSVJBG
# Feature n° 1028 : MUMGGOZAMZWBJJ
# Feature n° 895 : FXKCXGBBUBCRPU
# Feature n° 1317 : WWYNJERNGUHSAO
# Feature n° 687 : OBCJFTMGLMNCTJ
# Feature n° 468 : BYASTQVSNAVAKL
# Feature n° 1386 : RWXIFXNRCLMQCD
# Feature n° 512 : DYMROBVXGSLPAY
# Feature n° 664 : VIKNJXKGJWUCNN
# Feature n° 424 : WGVLKKXLCOUHPO
# Feature n° 618 : OKJCFMUGMSVJBG
# Feature n° 1421 : OKJCFMUGMSVJBG
# Feature n° 305 : OLPSAOWBSPXZEA

# %% [markdown]
# #### 3.2.2 Get the InChIKey for the NAP workflow (MetFrag candidate 1, 2 and 3) for the reaming features

# %%
draw_inchikey(df_final, 'MetFragSMILES1')
# Out:
# Feature n° 124 : PERPNFLGJXUDDW
# Feature n° 538 : NWPUHDAIOGMKFI
# Feature n° 624 : KVQQCXYORPHUQU
# Feature n° 420 : AXKQOCLPWRXCRI
# Feature n° 973 : PGZCJOPTDHWYES
# Feature n° 913 : ABGXDYHSMIYRIC
# Feature n° 983 : UGAGPNKCDRTDHP
# Feature n° 113 : PUGXDKPZBZICDX
# Feature n° 1309 : FKCPLBHSZGVMNG
# Feature n° 1043 : FOARYHMYWPXOBW
# Feature n° 450 : KVQQCXYORPHUQU
# Feature n° 1117 : GDAJTKZIGQRGOD
# Feature n° 521 : MVIYWFBLVAFZID
# Feature n° 559 : VDPJWHMYWDZZGX
# Feature n° 673 : VBEKTMIFJPKWJA
# Feature n° 940 : OJSKJQFODPKTBT
# Feature n° 102 : MOJZMWJRUKIQGL
# Feature n° 571 : QBAITYMIZWFOLG
# Feature n° 520 : VETWBGGPKLAQQE
# Feature n° 1183 : QWIXXDJUHXOKPB
# Feature n° 1031 : FZMONKRUPXQHKO
# Feature n° 1029 : UKOKENMLXFNPEJ
# Feature n° 1041 : LNWOKEZJIRLIDO
# Feature n° 30 : MOJZMWJRUKIQGL
# Feature n° 1646 : KUMASSYJGMPIHK
# Feature n° 872 : UGAGPNKCDRTDHP
# Feature n° 816 : AXKQOCLPWRXCRI
# Feature n° 1772 : KUMASSYJGMPIHK
# Feature n° 1116 : VZCCETWTMQHEPK
# Feature n° 592 : WSSLVRHDEOVNKI
# Feature n° 434 : FKCPLBHSZGVMNG
# Feature n° 894 : FKCPLBHSZGVMNG
# Feature n° 615 : HEIKHXMGSYQVGA
# Feature n° 706 : VBEKTMIFJPKWJA
# Feature n° 5 : MOJZMWJRUKIQGL
# Feature n° 871 : HGKRVDDOQIUQDS
# Feature n° 485 : VETWBGGPKLAQQE
# Feature n° 424 : UQDRWSKYMXNNHX
# Feature n° 1052 : FOARYHMYWPXOBW
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3163176862.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[str(cat + '_inchikey')].loc[df_final['shared name'] == x] = ik
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
# Feature n° 798 : UQDRWSKYMXNNHX
# Feature n° 942 : IQHBZJPFGJKKJI
# Feature n° 81 : MOJZMWJRUKIQGL
# Feature n° 655 : ZJGMUVOCFLKRTL
# Feature n° 1645 : RHCAOVDBFCREAC
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo

# %%
draw_inchikey(df_final, 'MetFragSMILES2')
# Out:
# Feature n° 538 : OWUWKGDMPZLWFL
# Feature n° 624 : ZPCDXXMKLPRLRL
# Feature n° 420 : MSWJSDLNPCSSNW
# Feature n° 973 : YWNVUSYLDSLXLI
# Feature n° 913 : DETZLZBJHDSRCR
# Feature n° 113 : PESNXVJICRFESF
# Feature n° 1309 : PORHOKHIMOFMMH
# Feature n° 450 : ZPCDXXMKLPRLRL
# Feature n° 1117 : FTCCXIDYXDLLRK
# Feature n° 521 : PKORXOLYTWDULG
# Feature n° 673 : REMAFSUYXZQVFM
# Feature n° 940 : YZXBAPSDXZZRGB
# Feature n° 571 : IGUDTNVZIOWVIV
# Feature n° 520 : FBZSMLWLLPEEKP
# Feature n° 1183 : PMKRDHYIJLQVRT
# Feature n° 1031 : JXHQWTYFUSHCGX
# Feature n° 1041 : QWIXXDJUHXOKPB
# Feature n° 816 : MSWJSDLNPCSSNW
# Feature n° 1116 : DTOSIQBPPRVQHS
# Feature n° 592 : IIWNDLDEVPJIBT
# Feature n° 434 : PORHOKHIMOFMMH
# Feature n° 894 : PORHOKHIMOFMMH
# Feature n° 615 : ALGYTGOYQATWBA
# Feature n° 706 : REMAFSUYXZQVFM
# Feature n° 871 : SECPZKHBENQXJG
# Feature n° 485 : FBZSMLWLLPEEKP
# Feature n° 942 : NFWKVWVWBFBAOV
# Feature n° 655 : QGBVBYUDRGXELK
# Feature n° 1645 : JLQCIOOODNXJEK
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3163176862.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[str(cat + '_inchikey')].loc[df_final['shared name'] == x] = ik
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo

# %%
draw_inchikey(df_final, 'MetFragSMILES3')
# Out:
# Feature n° 538 : TVDMUSYVWJLIDK
# Feature n° 420 : ISECDNAMJMNAHZ
# Feature n° 973 : ZHMKECHJAPXWCT
# Feature n° 913 : CQTHQCHQGAZGNF
# Feature n° 1309 : MLBYBBUZURKHAW
# Feature n° 1117 : WUENWZUJMIZJPA
# Feature n° 521 : IXORZMNAPKEEDV
# Feature n° 673 : BGKHCLZFGPIKKU
# Feature n° 940 : BTAURFWABMSODR
# Feature n° 571 : QMTZBWPBIQZLBJ
# Feature n° 1183 : LNWOKEZJIRLIDO
# Feature n° 1041 : PMKRDHYIJLQVRT
# Feature n° 816 : ISECDNAMJMNAHZ
# Feature n° 1116 : HXQHFNIKBKZGRP
# Feature n° 434 : RWWVEQKPFPXLGL
# Feature n° 894 : AYZMGUHJPVGYEB
# Feature n° 615 : CUXCAMYFFUWHQV
# Feature n° 706 : BGKHCLZFGPIKKU
# Feature n° 942 : PRZSMDYEVUSNJM
# Feature n° 655 : DEMNMQDWPCIOLA
# Feature n° 1645 : ZXOSMGNNWJODHY
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3163176862.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[str(cat + '_inchikey')].loc[df_final['shared name'] == x] = ik
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo
#
# [16:42:23] WARNING: Omitted undefined stereo

# %% [markdown]
# #### 3.3 Compare the annotation of the corresponding tool (GNPS, NAP) for the remaing features to the ones coming from 13C NMR workflow

# %%
def compare_to_nmr_annotation4a(df_smiles, df_common_sumup, cat, pre, suf):
    list_ID1=[]
    if len(df_common_sumup[cat].tolist()) == 0 :
        print('There is no left annotations to compare.')
    else:
        for x in range(len(df_common_sumup[cat].tolist())):

            for y in df_smiles['InchiKey'].tolist():
                if y in df_common_sumup[cat].tolist()[x]:
                    txt = int(df_common_sumup['shared name'].tolist()[x]), str(df_common_sumup[pre].tolist()[x] + ' ' + suf), df_smiles[0].tolist()[df_smiles['InchiKey'].tolist().index(y)]

                    list_ID1.append((txt))
        if len(list_ID1) == 0:
            print(f'There is no remaining candidate from {cat} matching with the 13C NMR workflow.')
        else:
            print(f'There are {len(list_ID1)} remaining candidates from {cat} that match with the 13C NMR workflow.' + '\n')
            for x in list_ID1:
                print(x)
    return list_ID1

# %% [markdown]
# #### 3.3.1 Compare the annotations from GNPS workflow for the remaing features to the 13C NMR ones

# %%
x0 = compare_to_nmr_annotation4a(df_smiles, df_final, 'Smiles_inchikey','SpectrumID', 'GNPS')
# Out:
# There is no remaining candidate from Smiles_inchikey matching with the 13C NMR workflow.

# %% [markdown]
# ##### Write results in the resume file

# %%
for x in x0:
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(x[0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=x[1]
    Dict_sumup['NAP_SU'][numerous]=None
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
    Dict_sumup['SIRIUS_SU'][numerous]=None
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]='NAP, SIRIUS'
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]= 1
    Dict_sumup['3rd_Tool_SU'][numerous]=None
    Dict_sumup['Molecular_Name_SU'][numerous]=x[-1]
    Dict_sumup['Confidence_Level'][numerous]=str(5)

# %% [markdown]
# ##### Apply confidence score = 5 to nodes with the GNPS remaining candidates that match with the 13C NMR annotations

# %%
for x in x0:
    df['All_Tools_confidence'][df['shared name'].to_list().index(x[0][0])] = 5

# %% [markdown]
# #### 3.3.2 Compare the remaning annotations from NAP (MetFrag candidates 1, 2 and 3) to the 13C NMR workflow

# %% [markdown]
# #### 3.3.2.1 Compare the annotations from NAP - MetFrag candidate 1, for the remaing features, to the 13C NMR workflow

# %%
x1 =compare_to_nmr_annotation4a(df_smiles, df_final, 'MetFragSMILES1_inchikey', 'MetFragID1' , 'MF1')
# Out:
# There are 1 remaining candidates from MetFragSMILES1_inchikey that match with the 13C NMR workflow.
#
# (124, 'LTS0251851 MF1', 'astringin')

# %% [markdown]
# ##### Write results in the resume file

# %%
for x in x1:
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(x[0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=None
    Dict_sumup['NAP_SU'][numerous]=x[1]
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
    Dict_sumup['SIRIUS_SU'][numerous]=None
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]='GNPS, SIRIUS'
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]= 1
    Dict_sumup['3rd_Tool_SU'][numerous]=None
    Dict_sumup['Molecular_Name_SU'][numerous]=x[2]
    Dict_sumup['Confidence_Level'][numerous]=str(7)

# %% [markdown]
# ##### Apply confidence score = 7 to nodes with the GNPS remaining candidates that match with the 13C NMR annotations

# %%
for x in x1:
    df['All_Tools_confidence'][df['shared name'].tolist().index(x[0])] = 7
# Out:
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\358549710.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['All_Tools_confidence'][df['shared name'].tolist().index(x[0])] = 7

# %% [markdown]
# #### 3.3.2.2 Compare the annotations from NAP - MetFrag candidate 2, for the remaing features, to the 13C NMR workflow_to_nmr_annotation

# %%
x2=compare_to_nmr_annotation4a(df_smiles, df_final, 'MetFragSMILES2_inchikey', 'MetFragID2', 'MF2')
# Out:
# There are 3 remaining candidates from MetFragSMILES2_inchikey that match with the 13C NMR workflow.
#
# (420, 'LTS0229171 MF2', '7-oxodehydroabietic-acid')
# (816, 'LTS0229171 MF2', '7-oxodehydroabietic-acid')
# (942, 'LTS0034017 MF2', 'dehydroabietic-acid')

# %% [markdown]
# ##### Write results in the resume file

# %%
for x in x2:
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(x[0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=None
    Dict_sumup['NAP_SU'][numerous]=x[1]
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
    Dict_sumup['SIRIUS_SU'][numerous]=None
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]='GNPS, SIRIUS'
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]= 1
    Dict_sumup['3rd_Tool_SU'][numerous]=None
    Dict_sumup['Molecular_Name_SU'][numerous]=x[2]
    Dict_sumup['Confidence_Level'][numerous]=str(7)

# %% [markdown]
# ##### Apply confidence score = 7 to nodes with the GNPS remaining candidates that match with the 13C NMR annotations

# %%
for x in x2:
    df['All_Tools_confidence'][df['shared name'].tolist().index(x[0])] = 7
# Out:
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\2854291149.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['All_Tools_confidence'][df['shared name'].tolist().index(x[0])] = 7

# %% [markdown]
# #### 3.3.2.3 Compare the annotations from NAP - MetFrag candidate 3, for the remaing features, to the 13C NMR workflow_to_nmr_annotation

# %%
x3=compare_to_nmr_annotation4a(df_smiles, df_final, 'MetFragSMILES3_inchikey', 'MetFragID3', 'MF3')
# Out:
# There is no remaining candidate from MetFragSMILES3_inchikey matching with the 13C NMR workflow.

# %% [markdown]
# ##### Write results in the resume file

# %%
for x in x3:
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(x[0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=None
    Dict_sumup['NAP_SU'][numerous]=x[1]
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
    Dict_sumup['SIRIUS_SU'][numerous]=None
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]='GNPS, SIRIUS'
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]= 1
    Dict_sumup['3rd_Tool_SU'][numerous]=None
    Dict_sumup['Molecular_Name_SU'][numerous]=x[2]
    Dict_sumup['Confidence_Level'][numerous]=str(7)

# %% [markdown]
# ##### Apply confidence score = 7 to nodes with the GNPS remaining candidates that match with the 13C NMR annotations

# %%
for x in x3:
    df['All_Tools_confidence'][df['shared name'].tolist().index(x[0])] = 7

# %% [markdown]
# #### 3.4 Configure the resume file

# %%
df_final = df_final.reset_index()

# %% [markdown]
# ##### 3.5 Now it is turn for SIRIUS annotations, for the reaming features, to be be compared to 13C NMR workflow ones

# %% [markdown]
# #### 3.5.1 Get the corresponding InChIkey for the candidates coming from the corresponding annotation workflow (SIRIUS)
# ##### /!\ This step could be a bit long... So, it is maybe time for a coffee ? /!\

# %%
for i in tqdm(range(len(df_final['shared name'].tolist())), unit ='Feature', desc ="SIRIUS features annotations recovered:" ):
    aa=''    
    filein =[x for x in list_folder if math.isnan(df_final['shared name'].tolist()[i])  == False and  str('_' + str(int(df_final['shared name'].tolist()[i]))) == x[-len(str('_' + str(int(df_final['shared name'].tolist()[i])))):]  ]
    if len(filein) !=0:
        os.chmod(filein[0], stat.S_IROTH)

        if os.path.exists(filein[0]+'/structure_candidates.tsv'):
            df_sirius_formula = pd.read_csv(filein[0]+'/structure_candidates.tsv', sep='\t')

            aa = df_sirius_formula['InChIkey2D'].tolist()
            df_final['SIRIUS_inchikey'][i] = aa
            
            list_formula_adduct=[]
            for formula in range(len(df_sirius_formula['molecularFormula'].tolist())):
                bb= df_sirius_formula['molecularFormula'].tolist()[formula] + df_sirius_formula['adduct'].tolist()[formula]
                list_formula_adduct.append(bb)
            df_final['SIRIUS_formula'][i] = list_formula_adduct
# Out:
# SIRIUS features annotations recovered::   0%|                                            | 0/1813 [00:00<?, ?Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   0%|                                    | 1/1813 [00:00<04:00,  7.52Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   0%|                                    | 2/1813 [00:00<04:02,  7.48Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   0%|                                    | 3/1813 [00:00<04:02,  7.46Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   0%|                                    | 4/1813 [00:00<04:03,  7.44Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   0%|                                    | 6/1813 [00:00<04:02,  7.44Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   0%|▏                                   | 7/1813 [00:00<04:02,  7.45Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   0%|▏                                   | 9/1813 [00:01<03:22,  8.92Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▏                                  | 10/1813 [00:01<03:32,  8.48Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▏                                  | 11/1813 [00:01<03:40,  8.16Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▏                                  | 12/1813 [00:01<03:46,  7.95Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▎                                  | 13/1813 [00:01<03:50,  7.79Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▎                                  | 14/1813 [00:01<03:54,  7.67Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▎                                  | 15/1813 [00:01<03:56,  7.60Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▎                                  | 18/1813 [00:02<03:56,  7.59Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▎                                  | 19/1813 [00:02<03:57,  7.55Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▍                                  | 20/1813 [00:02<03:57,  7.54Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▍                                  | 21/1813 [00:02<03:58,  7.52Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▍                                  | 22/1813 [00:02<03:59,  7.49Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▍                                  | 23/1813 [00:02<03:58,  7.51Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▍                                  | 24/1813 [00:03<03:58,  7.49Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▍                                  | 25/1813 [00:03<03:59,  7.48Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   1%|▌                                  | 26/1813 [00:03<03:58,  7.49Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▌                                  | 28/1813 [00:03<03:57,  7.51Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▌                                  | 29/1813 [00:03<03:58,  7.49Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▌                                  | 30/1813 [00:03<03:58,  7.49Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▌                                  | 31/1813 [00:04<03:57,  7.50Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▌                                  | 32/1813 [00:04<03:58,  7.47Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▋                                  | 33/1813 [00:04<03:58,  7.47Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▋                                  | 34/1813 [00:04<03:58,  7.47Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▋                                  | 35/1813 [00:04<03:58,  7.45Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▋                                  | 36/1813 [00:04<03:59,  7.42Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▊                                  | 39/1813 [00:05<03:18,  8.96Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▊                                  | 40/1813 [00:05<03:27,  8.53Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▊                                  | 41/1813 [00:05<03:35,  8.24Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▊                                  | 42/1813 [00:05<03:40,  8.03Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   2%|▊                                  | 44/1813 [00:05<03:45,  7.85Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|▉                                  | 46/1813 [00:05<03:49,  7.70Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|▉                                  | 47/1813 [00:06<03:51,  7.64Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|▉                                  | 48/1813 [00:06<03:52,  7.60Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|▉                                  | 49/1813 [00:06<03:54,  7.53Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|▉                                  | 50/1813 [00:06<03:54,  7.53Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|▉                                  | 51/1813 [00:06<03:55,  7.50Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|█                                  | 52/1813 [00:06<03:54,  7.52Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|█                                  | 53/1813 [00:06<03:54,  7.49Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|█                                  | 55/1813 [00:07<03:53,  7.54Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|█                                  | 56/1813 [00:07<03:54,  7.49Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|█                                  | 57/1813 [00:07<03:54,  7.48Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|█                                  | 58/1813 [00:07<03:54,  7.47Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|█▏                                 | 59/1813 [00:07<03:54,  7.49Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|█▏                                 | 60/1813 [00:07<03:54,  7.46Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|█▏                                 | 62/1813 [00:08<03:16,  8.89Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   3%|█▏                                 | 63/1813 [00:08<03:26,  8.47Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   4%|█▏                                 | 64/1813 [00:08<03:34,  8.15Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   4%|█▎                                 | 65/1813 [00:08<03:39,  7.96Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   4%|█▎                                 | 66/1813 [00:08<03:43,  7.82Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   4%|█▎                                 | 67/1813 [00:08<03:46,  7.69Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   4%|█▎                                 | 68/1813 [00:08<03:48,  7.62Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   4%|█▎                                 | 70/1813 [00:09<03:48,  7.63Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::   4%|█▎                                 | 71/1813 [00:09<03:49,  7.58Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# ...
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::  99%|████████████████████████████████▌| 1790/1813 [03:52<00:03,  7.54Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::  99%|████████████████████████████████▌| 1791/1813 [03:52<00:02,  7.55Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::  99%|████████████████████████████████▌| 1792/1813 [03:52<00:02,  7.54Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::  99%|████████████████████████████████▋| 1793/1813 [03:52<00:02,  7.54Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::  99%|████████████████████████████████▋| 1794/1813 [03:52<00:02,  7.54Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::  99%|████████████████████████████████▋| 1795/1813 [03:52<00:02,  7.54Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::  99%|████████████████████████████████▋| 1796/1813 [03:53<00:02,  7.49Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::  99%|████████████████████████████████▋| 1798/1813 [03:53<00:01,  7.56Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::  99%|████████████████████████████████▋| 1799/1813 [03:53<00:01,  7.55Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::  99%|████████████████████████████████▊| 1800/1813 [03:53<00:01,  7.58Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::  99%|████████████████████████████████▊| 1801/1813 [03:53<00:01,  7.55Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered::  99%|████████████████████████████████▊| 1802/1813 [03:53<00:01,  7.54Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered:: 100%|████████████████████████████████▊| 1804/1813 [03:54<00:01,  7.59Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered:: 100%|████████████████████████████████▊| 1805/1813 [03:54<00:01,  7.59Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered:: 100%|████████████████████████████████▊| 1806/1813 [03:54<00:00,  7.56Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered:: 100%|████████████████████████████████▉| 1807/1813 [03:54<00:00,  7.56Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered:: 100%|████████████████████████████████▉| 1808/1813 [03:54<00:00,  7.52Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered:: 100%|████████████████████████████████▉| 1809/1813 [03:54<00:00,  7.54Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered:: 100%|████████████████████████████████▉| 1811/1813 [03:55<00:00,  7.56Feature/s]C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_inchikey'][i] = aa
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\671493810.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['SIRIUS_formula'][i] = list_formula_adduct
# SIRIUS features annotations recovered:: 100%|█████████████████████████████████| 1813/1813 [03:55<00:00,  7.71Feature/s]

# %% [markdown]
# #### 3.5.2 Compare the  SIRIUS annotations, for the remaing features, to the ones coming from 13C NMR workflow

# %%
def compare_to_nmr_annotation4b(df_smiles, df_common_sumup, cat):
    list_ID1=[]
    if len(df_common_sumup) == 0:
        print('There is no corresponding feature for this comparison.')
    else:
        for x in range(len(df_common_sumup[cat].tolist())):

            for y in df_smiles['InchiKey'].tolist():

                if y in df_common_sumup[cat][x]:

                    txt = int(df_common_sumup['shared name'].tolist()[x]), y,  df_common_sumup['SIRIUS_formula'][x][df_common_sumup[cat][x].index(y)], df_smiles[0].tolist()[df_smiles['InchiKey'].tolist().index(y)]

                    list_ID1.append((txt))
        if len(list_ID1) == 0 :
            print('There is no match between remaing SIRIUS annotations and 13C NMR workflow ones.')
        else:
            print(f'There are {len(list_ID1)} features with a reamaing SIRIUS annotation that match with one of the 13C NMR workflow.' + '\n')
            for x in list_ID1:
                print(x)
    return list_ID1

# %%
x4=compare_to_nmr_annotation4b(df_smiles, df_final, 'SIRIUS_inchikey')
# Out:
# There are 42 features with a reamaing SIRIUS annotation that match with one of the 13C NMR workflow.
#
# (250, 'PFTAWBLQPZVEMU', 'C15H14O6[M - H2O + H]+', 'catechin')
# (250, 'PFTAWBLQPZVEMU', 'C15H14O6[M - H2O + H]+', 'catechin')
# (209, 'OYHQOLUKZRVURQ', 'C18H32O2[M + Na]+', 'linoleic-acid')
# (935, 'NFWKVWVWBFBAOV', 'C20H28O2[M - H2O + H]+', 'dehydroabietic-acid')
# (700, 'KSEBMYQBYZTDHS', 'C10H10O4[M - H2O + H]+', 'ferulic-acid')
# (743, 'NFWKVWVWBFBAOV', 'C20H28O2[M - H2O + H]+', 'dehydroabietic-acid')
# (1253, 'NFWKVWVWBFBAOV', 'C20H28O2[M + Na]+', 'dehydroabietic-acid')
# (1099, 'MXYATHGRPJZBNA', 'C20H30O2[M - H4O2 + H]+', 'isopimaric-acid')
# (76, 'PFTAWBLQPZVEMU', 'C15H14O6[M - H2O + H]+', 'catechin')
# (76, 'PFTAWBLQPZVEMU', 'C15H14O6[M - H2O + H]+', 'catechin')
# (1230, 'KSEBMYQBYZTDHS', 'C10H10O4[M - H2O + H]+', 'ferulic-acid')
# (958, 'OYHQOLUKZRVURQ', 'C18H32O2[M - H4O2 + H]+', 'linoleic-acid')
# (460, 'MSWJSDLNPCSSNW', 'C20H26O3[M - H2O + H]+', '7-oxodehydroabietic-acid')
# (856, 'NFWKVWVWBFBAOV', 'C20H28O2[M - H2O + H]+', 'dehydroabietic-acid')
# (159, 'PERPNFLGJXUDDW', 'C20H22O9[M + H]+', 'astringin')
# (678, 'MSWJSDLNPCSSNW', 'C20H26O3[M - H2O + H]+', '7-oxodehydroabietic-acid')
# (1184, 'NFWKVWVWBFBAOV', 'C20H28O2[M - H2O + H]+', 'dehydroabietic-acid')
# (386, 'MSWJSDLNPCSSNW', 'C20H26O3[M + H]+', '7-oxodehydroabietic-acid')
# (1279, 'MSWJSDLNPCSSNW', 'C20H26O3[M + H]+', '7-oxodehydroabietic-acid')
# (1036, 'KSEBMYQBYZTDHS', 'C10H10O4[M - H2O + H]+', 'ferulic-acid')
# (1047, 'CECREIRZLPLYDM', 'C20H34O[M - H2O + H]+', '13-epimanool')
# (494, 'MSWJSDLNPCSSNW', 'C20H26O3[M + H]+', '7-oxodehydroabietic-acid')
# (1182, 'WCNCDVQMEQJFGH', 'C22H36O3[M - H2O + H]+', 'larixyl-acetate')
# (1073, 'MXYATHGRPJZBNA', 'C20H30O2[M + H]+', 'isopimaric-acid')
# (960, 'OYHQOLUKZRVURQ', 'C18H32O2[M - H2O + H]+', 'linoleic-acid')
# (57, 'KSEBMYQBYZTDHS', 'C10H10O4[M - H2O + H]+', 'ferulic-acid')
# (959, 'OYHQOLUKZRVURQ', 'C18H32O2[M + H]+', 'linoleic-acid')
# (400, 'MSWJSDLNPCSSNW', 'C20H26O3[M - H2O + H]+', '7-oxodehydroabietic-acid')
# (1328, 'KSEBMYQBYZTDHS', 'C10H10O4[M - H2O + H]+', 'ferulic-acid')
# (978, 'MXYATHGRPJZBNA', 'C20H30O2[M + H]+', 'isopimaric-acid')
# (583, 'MSWJSDLNPCSSNW', 'C20H26O3[M - H2O + H]+', '7-oxodehydroabietic-acid')
# (196, 'KSEBMYQBYZTDHS', 'C10H10O4[M - H2O + H]+', 'ferulic-acid')
# (436, 'NFWKVWVWBFBAOV', 'C20H28O2[M + H]+', 'dehydroabietic-acid')
# (1910, 'KSEBMYQBYZTDHS', 'C10H10O4[M - H2O + H]+', 'ferulic-acid')
# (630, 'MXYATHGRPJZBNA', 'C20H30O2[M - H4O2 + H]+', 'isopimaric-acid')
# (495, 'MSWJSDLNPCSSNW', 'C20H26O3[M - H2O + H]+', '7-oxodehydroabietic-acid')
# (461, 'MSWJSDLNPCSSNW', 'C20H26O3[M + H]+', '7-oxodehydroabietic-acid')
# (2014, 'NFWKVWVWBFBAOV', 'C20H28O2[M + H]+', 'dehydroabietic-acid')
# (1194, 'KSEBMYQBYZTDHS', 'C10H10O4[M - H2O + H]+', 'ferulic-acid')
# (1617, 'KSEBMYQBYZTDHS', 'C10H10O4[M - H2O + H]+', 'ferulic-acid')
# (1160, 'MXYATHGRPJZBNA', 'C20H30O2[M + H]+', 'isopimaric-acid')
# (1340, 'MSWJSDLNPCSSNW', 'C20H26O3[M + H]+', '7-oxodehydroabietic-acid')

# %% [markdown]
# ##### Write results in the resume file
# ##### Apply confidence score = 6 to nodes with the SIRIUS candidates that match with the 13C NMR annotations

# %%
for x in x4:
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(x[0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=None
    Dict_sumup['NAP_SU'][numerous]=None
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
    Dict_sumup['SIRIUS_SU'][numerous]=str(x[1] + ' ' + x[2])
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]='GNPS, NAP'
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]= 1
    Dict_sumup['3rd_Tool_SU'][numerous]=None
    Dict_sumup['Molecular_Name_SU'][numerous]=x[-1]
    Dict_sumup['Confidence_Level'][numerous]=str(6)

# %% [markdown]
# ## 4. Final step: compare the annotation from the remaining Mass workflow that did not match with another one

# %% [markdown]
# #### 4.1 Compare the last Mass annotation results (GNPS or NAP), to the 13C NMR candidates

# %%
def compare_3rd_tool_NAP_or_GNPS(job_tupple,cat):
    name_out=[]
    
    if len(job_tupple) !=0:
        for x in job_tupple:
            m = Chem.MolFromSmiles(df[cat].loc[df['shared name'] == x[0]].tolist()[0])
            ic=Chem.MolToInchi(m)
            ik=Chem.rdinchi.InchiToInchiKey(ic).split('-')[0]
#             print(ik)
            if ik in df_smiles['InchiKey']:
                name_out.append((x[0], df_smiles[0].loc[df_smiles['InchiKey'] == ik].tolist()[0]), str(cat+'_3rd_tool_that_didnot_match'))
        if len(name_out) == 0 :
            print('There is no match for this last comparison.')
        else:
            print(f'There are {len(name_out)} features with the last Mass tool annotation that match a 13C NMR candidate.' + '\n')
            for x in name_out:
                print(x)
    else:
        print('There is no corresponding feature for this last comparison.')
        
    return name_out

# %% [markdown]
# #### 4.1.1 If the last Mass tool to compare is GNPS

# %%
xc1o = compare_3rd_tool_NAP_or_GNPS(xc1,'Smiles')
# Out:
# There is no match for this last comparison.
# [16:46:20] WARNING: Omitted undefined stereo

# %% [markdown]
# ##### Write results in the resume file
# ##### Apply confidence score = 13 to nodes with the GNPS candidate that match with the 13C NMR annotations

# %%
for x in xc1o:
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(x[0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=None
    Dict_sumup['NAP_SU'][numerous]=None
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
    Dict_sumup['SIRIUS_SU'][numerous]=None
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]=None
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]= 1
    Dict_sumup['3rd_Tool_SU'][numerous]=str(x[1] + ' ' + x[2])
    Dict_sumup['Molecular_Name_SU'][numerous]=None
    Dict_sumup['Confidence_Level'][numerous]=str(13)

# %% [markdown]
# #### 4.1.2 If the last Mass tool to compare is NAP - MetFrag candidate 1, 2 and 3

# %% [markdown]
# #### 4.1.2.1 For MetFrag candidate 1

# %%
xb1o_a = compare_3rd_tool_NAP_or_GNPS(xb1,'MetFragSMILES1')
# Out:
# There is no corresponding feature for this last comparison.

# %% [markdown]
# ##### Write results in the resume file
# ##### Apply confidence score = 15 to nodes with the MetFrag candidate 1 that match with the 13C NMR annotations

# %%
for x in xb1o_a:
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(x[0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=None
    Dict_sumup['NAP_SU'][numerous]=None
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
    Dict_sumup['SIRIUS_SU'][numerous]=None
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]=None
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]= 1
    Dict_sumup['3rd_Tool_SU'][numerous]=str(x[1] + ' ' + x[2])
    Dict_sumup['Molecular_Name_SU'][numerous]=None
    Dict_sumup['Confidence_Level'][numerous]=str(15)

# %% [markdown]
# #### 4.1.2.2 For MetFrag candidate 2

# %%
xb1o_b = compare_3rd_tool_NAP_or_GNPS(xb1,'MetFragSMILES2')
# Out:
# There is no corresponding feature for this last comparison.

# %% [markdown]
# ##### Write results in the resume file
# ##### Apply confidence score = 15 to nodes with the MetFrag candidate 2  that match with the 13C NMR annotations

# %%
for x in xb1o_b:
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(x[0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=None
    Dict_sumup['NAP_SU'][numerous]=None
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
    Dict_sumup['SIRIUS_SU'][numerous]=None
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]=None
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]= 1
    Dict_sumup['3rd_Tool_SU'][numerous]=str(x[1] + ' ' + x[2])
    Dict_sumup['Molecular_Name_SU'][numerous]=None
    Dict_sumup['Confidence_Level'][numerous]=str(15)

# %% [markdown]
# #### 4.1.2.3 For MetFrag candidate 3

# %%
xb1o_c = compare_3rd_tool_NAP_or_GNPS(xb1,'MetFragSMILES3')
# Out:
# There is no corresponding feature for this last comparison.

# %% [markdown]
# ##### Write results in the resume file
# ##### Apply confidence score = 15 to nodes with the MetFrag candidate 3 that match with the 13C NMR annotations

# %%
for x in xb1o_c:
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(x[0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=None
    Dict_sumup['NAP_SU'][numerous]=None
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
    Dict_sumup['SIRIUS_SU'][numerous]=None
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]=None
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]= 1
    Dict_sumup['3rd_Tool_SU'][numerous]=str(x[1] + ' ' + x[2])
    Dict_sumup['Molecular_Name_SU'][numerous]=None
    Dict_sumup['Confidence_Level'][numerous]=str(15)

# %% [markdown]
# #### 4.1.3 If the last Mass tool to compare is SIRIUS

# %%
def compare_3rd_tool_SIRIUS():
    name_out=[]
    if len(xb2) !=0:
        for y in xb2:
    #         print(y)
            filein =[x for x in list_folder if  str('_' + str(y[0])) == x[-len('_' + str(y[0])):]]
            if len(filein)!=0:
                os.chmod(filein[0], stat.S_IROTH)

                if os.path.exists(filein[0]+'/structure_candidates.tsv'):
                    df_sirius_formula = pd.read_csv(filein[0]+'/structure_candidates.tsv', sep='\t')
                    sirius_inchikey_list=df_sirius_formula['InChIkey2D'].tolist()
#                     print(sirius_inchikey_list)
                    for ik in sirius_inchikey_list:
                        if ik in df_smiles['InchiKey'].tolist():
                            name_out.append((y[0],df_smiles[0].loc[df_smiles['InchiKey'] == ik].tolist()[0], 'SIRIUS_3rd_tool_that_didnot_match'))
        if len(name_out) == 0 :
            print('There is no match for this last comparison.')
        else:
            print(f'There are {len(name_out)} features with the last Mass tool annotation that match a 13C NMR candidate.' + '\n')
            for x in name_out:
                print(x)
    else:
        print('There is no corresponding feature for this last comparison.')
    return name_out

# %%
xb2o = compare_3rd_tool_SIRIUS()
# Out:
# There is no corresponding feature for this last comparison.

# %% [markdown]
# ##### Write results in the resume file
# ##### Apply confidence score = 14 to nodes with the SIRIUS candidates that match with the 13C NMR annotations

# %%
for x in xb2o:
    numerous=numerous+1
    Dict_sumup['Feature_SU'][numerous]=int(x[0])
    Dict_sumup['Rt_SU'][numerous]=None
    Dict_sumup['GNPS_SU'][numerous]=None
    Dict_sumup['NAP_SU'][numerous]=None
    Dict_sumup['MolNetEnhancer_SU'][numerous]=None
    Dict_sumup['SIRIUS_SU'][numerous]=None
    Dict_sumup['Not_Matching_Tool_Annotation_SU'][numerous]=None
    Dict_sumup['Is_NMR_Annotated_SU'][numerous]= 1
    Dict_sumup['3rd_Tool_SU'][numerous]=str(x[1] + ' ' + x[2])
    Dict_sumup['Molecular_Name_SU'][numerous]=None
    Dict_sumup['Confidence_Level'][numerous]=str(14)

# %% [markdown]
# ## 5. Finalize the results file

# %%
df_resume= pd.DataFrame.from_dict(Dict_sumup)

# %% [markdown]
# #### 5.1 Add the corresponding 13C NMR candidate(s) name to the final results

# %%
for x in xa:
    if x[0] in df_resume['Feature_SU'].tolist():
        df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
        df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
        df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 1

for x in xb1:
    if x[0] in df_resume['Feature_SU'].tolist():
        df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
        df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
        df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 4

for x in xb2:
    if x[0] in df_resume['Feature_SU'].tolist():
        df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
        df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
        df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 2

for x in xc1:
    if x[0] in df_resume['Feature_SU'].tolist():
        df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
        df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
        df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = '3+'

for x in xc2:
    if x[0] in df_resume['Feature_SU'].tolist():
        df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
        df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
        df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 3



for x in x0:
    if x[0] in df_resume['Feature_SU'].tolist():
        df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
        df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
        df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 5

for x in x1:
    if x[0] in df_resume['Feature_SU'].tolist():
        df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
        df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
        df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 7

for x in x2:
    if x[0] in df_resume['Feature_SU'].tolist():
        df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
        df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
        df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 7

for x in x3:
    if x[0] in df_resume['Feature_SU'].tolist():
        df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
        df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
        df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 7

for x in x4:
    if x[0] in df_resume['Feature_SU'].tolist():
        df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
        df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
        df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 6
# Out:
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = '3+'
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 3
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 7
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 7
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Is_NMR_Annotated_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = 1
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Molecular_Name_SU'][df_resume['Feature_SU'].tolist().index(x[0])] = x[-1]
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\3106139829.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Confidence_Level'][df_resume['Feature_SU'].tolist().index(x[0])] = 6

# %% [markdown]
# #### 5.2 Add the corresponding NPClassifier infos, m/z and Retention time (Rt) for each feaute, to the final results

# %%
for x in df_resume['Feature_SU'].tolist():
    if x in df['shared name'].tolist():

        df_resume['MolNetEnhancer_SU'][df_resume['Feature_SU'].tolist().index(x)] = df['npclassifier_superclass'][df['shared name'].tolist().index(x)]
        df_resume['Rt_SU'][df_resume['Feature_SU'].tolist().index(x)] = df['RTConsensus'][df['shared name'].tolist().index(x)]
        df_resume['m/z'][df_resume['Feature_SU'].tolist().index(x)] = df['row m/z'][df['shared name'].tolist().index(x)]
df_resume.rename(columns = {'MolNetEnhancer_SU':'NPClassifier_superclass_SU'}, inplace = True)
# Out:
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\44682415.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['MolNetEnhancer_SU'][df_resume['Feature_SU'].tolist().index(x)] = df['npclassifier_superclass'][df['shared name'].tolist().index(x)]
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\44682415.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['Rt_SU'][df_resume['Feature_SU'].tolist().index(x)] = df['RTConsensus'][df['shared name'].tolist().index(x)]
# C:\Users\jcrdnr\AppData\Local\Temp\ipykernel_10888\44682415.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resume['m/z'][df_resume['Feature_SU'].tolist().index(x)] = df['row m/z'][df['shared name'].tolist().index(x)]

# %% [markdown]
# ##### If you want to vizualize the final results, please run the cell below.

# %%
df_resume
# Out:
#      Feature_SU         m/z    Rt_SU             GNPS_SU          NAP_SU  \
# 0           190  303.050409   4.5092  CCMSLIB00005739139  LTS0004651 MF2
# 1            51  579.150185   2.6637  CCMSLIB00005742589  LTS0066122 MF1
# 2           283  287.055699   5.1329  CCMSLIB00005748053  LTS0155822 MF1
# 3           367  287.055521   7.0902  CCMSLIB00005749366  LTS0155822 MF1
# 4            60  291.086742   2.9239  CCMSLIB00005742701  LTS0265245 MF1
# ..          ...         ...      ...                 ...             ...
# 186        2014  301.216685  21.6678                None            None
# 187        1194  177.055194  17.1851                None            None
# 188        1617  177.055104  20.0258                None            None
# 189        1160  303.231609  16.8989                None            None
# 190        1340  315.196131  18.6847                None            None
#
#     NPClassifier_superclass_SU                              SIRIUS_SU  \
# 0                   Flavonoids        REFJWTPEDVJJIY C15H10O7[M + H]+
# 1                   Flavonoids       XFZJEEAOWLFHDH C30H26O12[M + H]+
# 2                   Flavonoids        IYRMWMYZSQPJKC C15H10O6[M + H]+
# 3                   Flavonoids        IYRMWMYZSQPJKC C15H10O6[M + H]+
# 4                   Flavonoids        PFTAWBLQPZVEMU C15H14O6[M + H]+
# ..                         ...                                    ...
# 186                        NaN        NFWKVWVWBFBAOV C20H28O2[M + H]+
# 187                        NaN  KSEBMYQBYZTDHS C10H10O4[M - H2O + H]+
# 188                        NaN  KSEBMYQBYZTDHS C10H10O4[M - H2O + H]+
# 189                        NaN        MXYATHGRPJZBNA C20H30O2[M + H]+
# 190                        NaN        MSWJSDLNPCSSNW C20H26O3[M + H]+
#
#     Not_Matching_Tool_Annotation_SU  Is_NMR_Annotated_SU 3rd_Tool_SU  \
# 0                              None                  NaN        None
# 1                              None                  NaN        None
# 2                              None                  NaN        None
# 3                              None                  NaN        None
# 4                              None                  1.0        None
# ..                              ...                  ...         ...
# 186                       GNPS, NAP                  1.0        None
# 187                       GNPS, NAP                  1.0        None
# 188                       GNPS, NAP                  1.0        None
# 189                       GNPS, NAP                  1.0        None
# 190                       GNPS, NAP                  1.0        None
#
#             Molecular_Name_SU Confidence_Level
# 0                        None                9
# 1                        None                9
# 2                        None                9
# 3                        None                9
# 4                    catechin                1
# ..                        ...              ...
# 186       dehydroabietic-acid                6
# 187              ferulic-acid                6
# 188              ferulic-acid                6
# 189           isopimaric-acid                6
# 190  7-oxodehydroabietic-acid                6
#
# [191 rows x 12 columns]

# %% [markdown]
# # /!\ Write the results file that resumes all the above comparisons /!\
#
# Just replace the red name between quotation marks in the cell bellow.

# %%
filout = df_resume.to_csv(resume_file_path, sep='\t', index=False)

# %% [markdown]
# #### Get the annotations that are only found by NMR (CaraMel) workflow

# %%
CaraMel_single_annotation = [(x,df_smiles[1].tolist()[df_smiles[0].tolist().index(x)]) for x in df_smiles[0].tolist() if x not in df_resume['Molecular_Name_SU'].unique().tolist()]
for x in CaraMel_single_annotation:
    print(x)
# Out:
# ('epicatechin', 'C1[C@H]([C@H](OC2=CC(=CC(=C21)O)O)C3=CC(=C(C=C3)O)O)O')
# ('acetic_acid', 'CC(=O)O')
# ('piceatannol-3-o-glucoside', 'C1=CC(=C(C=C1/C=C/C2=CC(=CC(=C2)O)O)O[C@H]3[C@@H]([C@H]([C@@H]([C@H](O3)CO)O)O)O)O')
# ('glucosyl-frambinone', 'CC(=O)CCC1=CC=C(C=C1)OC2C(C(C(C(O2)CO)O)O)O')
# ('glycerol-monoacetate', 'CC(=O)OCC(CO)O')
# ('lavandoside', 'COC1=C(C=CC(=C1)/C=C/C(=O)O)O[C@H]2[C@@H]([C@H]([C@@H]([C@H](O2)CO)O)O)O')
# ('glucosyl-trans-paracoumaric-acid', 'C1=CC(=CC=C1/C=C/C(=O)O)O[C@H]2[C@@H]([C@H]([C@@H]([C@H](O2)CO)O)O)O')
# ('compound-a', 'OC1=C(CC(O)=O)C(OC(C2=CC=C(O)C=C2)=O)=CC(O)=C1')
# ('dianthoside', 'CC1=C(C(=O)C=CO1)O[C@H]2[C@@H]([C@H]([C@@H]([C@H](O2)CO)O)O)O')
# ('arabinosyl-glucosyl-myrtenic-acid', 'CC1([C@H]2C(C(O[C@H]3[C@@H]([C@H]([C@@H]([C@H](O3)CO[C@H]4[C@@H]([C@H]([C@H](CO4)O)O)O)O)O)O)=O)=CC[C@@H]1C2)C')
# ('rhamnosyl-glucosyl-myrtenic-acid', 'CC1(C)C2C(C(O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C@@H](CO[C@H]4[C@H](O)[C@H](O)[C@@H](O)[C@H](C)O4)O3)=O)=CCC1C2')
# ('oleic-acid', 'CCCCCCCC/C=C\\CCCCCCCC(=O)O')

# %% [markdown]
# This is a sum-up of the name of the list for the different comparisons:
# - xa → gnps_sirus_nap common annotation features
# - xb1 →gnps_nap common annotation features
# - xb2 → gnps_sirius common annotation features
# - xc1→ nap_sirius common annotation features, with a different gnps candidate
# - xc2 → nap_siriuscommon annotation features without any gnps candidate
#
# - x0 → gnps_13CNMR, if the features do not have a common annotation between at least 2 different Mass annotation workflow
# - x1 → MetFrag1_13CNMR, , if the features do not have a common annotation between at least 2 different Mass annotation workflow
# - x2 → MetFrag2_13CNMR, , if the features do not have a common annotation between at least 2 different Mass annotation workflow
# - x3 → MetFrag3_13CNMR, , if the features do not have a common annotation between at least 2 different Mass annotation workflow
# - x4 → sirius_13CNMR, , if the features do not have a common annotation between at least 2 different Mass annotation workflow
#
# - xb1o_a → MetFrag1_13CNMR, if the features have a common annotation between gnps and sirius
# - xb1o_b → MetFrag2, if the features have a common annotation between gnps and sirius
# - xb1o_c → MetFrag3, if the features have a common annotation between gnps and sirius
# - xb2o → SIRIUS, if the features have a common annotation between gnps and nap
# - xc1o → GNPS, if the features have a common annotation between nap and sirius
